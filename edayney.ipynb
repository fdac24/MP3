# %%
import sys
print(sys.version)
# Out:
# 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)]

# %%
# %pip install requests
# %pip install urlextract
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: requests in c:\users\elija\appdata\local\programs\python\python311\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\elija\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\elija\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\elija\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elija\appdata\local\programs\python\python311\lib\site-packages (from requests) (2024.8.30)
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: urlextract in c:\users\elija\appdata\local\programs\python\python311\lib\site-packages (1.9.0)
# Requirement already satisfied: idna in c:\users\elija\appdata\local\programs\python\python311\lib\site-packages (from urlextract) (3.10)
# Requirement already satisfied: uritools in c:\users\elija\appdata\local\programs\python\python311\lib\site-packages (from urlextract) (4.0.3)
# Requirement already satisfied: platformdirs in c:\users\elija\appdata\roaming\python\python311\site-packages (from urlextract) (4.3.6)
# Requirement already satisfied: filelock in c:\users\elija\appdata\local\programs\python\python311\lib\site-packages (from urlextract) (3.16.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json, re
import requests
from urlextract import URLExtract
import sys, gzip

utid = 'edayney' # For output file

# Base URLs for different repository types
base= { 'model':'https://huggingface.co/', 'data': 'https://huggingface.co/datasets/', 'source': 'https://' }

# README paths for huggingface and github respectively
post = '/raw/main/README.md'
postGH = 'blob/master/README.md' # or it could be 'blob/main/README.md'

# Store URLExtract object for use in URL extraction functions
extU = URLExtract()
DOIpattern = r'\b(10\.\d{4,9}\/[-._;()/:A-Z0-9]+)\b/i'
#r1\b(10[.][0-9]{4,}(?:[.][0-9]+)*/(?:(?!["&\'<>])[[:graph:]])+)\b'

# Extracts all URLs in the content
def extractURLs (c):
 res = extU.find_urls (c)
 return res

# Extracts all Digital Object Identifiers in the content
def extractDOIs (c):
 res = re.findall (DOIpattern, c)
 return res

# Functional output? Sends output to json file
fo = gzip.open(f"output/{utid}.json.gz", 'w')

def run (tp):
 # Used to build the path to the README files
 post0 = post
 with open(f"input/{utid}_{tp}", 'r') as f:
  for line in f:
   line = line.strip ()
   if tp == 'source':
    (npapers,line) = line.split(';');
    post0 = postGH
   print(line)
   
   # Build out the URL to the README file
   url = base[tp] + f"{line}{post0}"
   r = requests.get (url)
   content = r.text
   
   #github returns repos that do not exist, need to detect that here
   #github when you give master instead of main, that might cause issues as well
   urls = extractURLs(content)
   dois = extractDOIs(content)
   res = { 'ID': line, 'type': tp, 'url': url, 'content': content, 'links': urls, 'dois': dois }
   out = json.dumps(res, ensure_ascii=False)
   fo.write((out+"\n").encode())

run('model')
print("FINISHED MODEL PORTION")
run('data')
print("FINISHED DATA PORTION")
run('source')
print("FINISHED SOURCE PORTION")
# Out:
# mradermacher/LCARS_AI_001-i1-GGUF
# QizhiPei/biot5-base
# mradermacher/Mixtral_AI_CyberUltron-GGUF
# multimolecule/splicebert.510nt
# scvi-tools/tabula-sapiens-vasculature-scvi
# cloudyu/Llama-3-70Bx2-MOE
# mlx-community/Dolphin-2.9.3-Mistral-Nemo-12b-bf16
# approach0/dpr-cocondenser-520
# CCRss/topic_modeling_top2vec_scientific-texts
# iamacaru/climate
# slezki/stable-test
# shuyuej/metamath_lora_llama2_7b_2_epoch
# ymath/stego-classifier-checkpoint-epoch-1-1111
# mradermacher/WestSeverus-7B-DPO-v2-ORPO-GGUF
# kobe-ja/math_test
# EarthnDusk/EarthnDusk_SDXL_Models
# hyunjongkimmath/def_and_notat_token_classification_model
# CMU-AIR2/math-phi-1-5-FULL-Arithmetic-Curriculum-Subjects-8-to-10
# EmbeddedLLM/Mistral-7B-Merge-14-v0.3
# Suhong/distilbert-base-uncased-emotion-climateChange
# 1aurent/wide_resnet50_2.tiatoolbox-pcam
# MaziyarPanahi/Experiment27pasticheT3q-7B-GGUF
# zhangtaolab/plant-dnamamba-lncRNAs
# hw2942/chinese-macbert-base-climate-related-prediction-vv1
# EarthnDusk/Feb2024-SD15
# LoneStriker/DiscoLM-70b-5.0bpw-h6-exl2
# ZeroWw/gemma-2-9b-SBS
# rjnClarke/sentence-transformers-all-MiniLM-L6-v2-fine-tuned
# EarthnDusk/August_2024
# Mathys1/testGPT
# ekorman-strive/bge-large-en-v1.5
# michaelfeil/ct2fast-jina-embedding-l-en-v1
# GT4SD/multitask-text-and-chemistry-t5-base-augm
# universeTBD/astrollama.gguf
# Kampf1/GPT_SoVITS
# itsGanni/2008_Sichuan_earthquake-clustered
# RichardErkhov/We-Want-GPU_-_Yi-Ko-6B-orca-alpaca-gpt4-math-gguf
# mradermacher/mistral-nemo-bophades-12B-i1-GGUF
# vwxyzjn/summarize_from_feedback_details
# dyk34/Training-Data-MathSearch
# mespinosami/controlearth
# tdc/herg_karim-CNN
# HuangLab/CELL-E_2_HPA_Finetuned_640
# mradermacher/dolphin-2.9.2-mixtral-8x22b-GGUF
# EpistemeAI/MathLlama3.1-8B-16bit-ORPO-4bit-gguf
# AmelieSchreiber/esm2_t12_35M_weighted_lora_rna_binding
# musarehmani100/automatisch
# magistermilitum/roberta-multilingual-medieval-ner
# hw2942/bert-base-chinese-climate-transition-physical-risk-prediction-5
# legraphista/dolphin-2.9.1-llama-3-70b-IMat-GGUF
# ai2lumos/lumos_maths_plan_iterative-13B
# LoneStriker/openchat-3.5-1210-3.0bpw-h6-exl2-2
# InstaDeepAI/nucleotide-transformer-500m-1000g
# CMU-AIR2/math-phi-1-5-FULL-MWP-6k
# LoneStriker/dolphin-2.9.1-llama-3-8b-3.0bpw-h6-exl2
# louisbrulenaudet/Maxine-7B-0401-stock
# shoemaker/L3.1-8B-sunfall-v0.6.1-dpo-Q8_0-GGUF
# DavidAU/TinyLlama-1.1bee-Q8_0-GGUF
# SM0rc/mathleaks_desc_to_code_llama70bl
# Vawka/Metavaw
# mlx-community/dolphin-2.9.3-Yi-1.5-34B-32k-8bit
# hubii-world/ECG2HRV
# mnemic/ElementEarth-SD1.5-LoRA
# surya-narayanan/chemistry_non_masked
# serdarcaglar/primary-school-math-question
# kiendt/vinallama-math-7b
# bluesky333/medphi2
# KakaoL0L/Mistral7B_MatheoAI_lora
# openclimatefix/pvnet_v2_summation
# OliveiraJLT/Sagui-7B-Instruct-v0.1
# Brian314/pix2text-mfr-quantized
# joshnader/deepseek-math-7b-instruct-Q8_0-GGUF
# ALBADDAWI/DeepCode-7B-Aurora-v5
# LoneStriker/SeaLLM-7B-v2-3.0bpw-h6-exl2
# LoneStriker/Smaug-Llama-3-70B-Instruct-4.0bpw-h6-exl2
# 1aurent/resnext101_32x8d.tiatoolbox-pcam
# Rimyy/LLAmaFineTuneNewDataMath
# BVRA/tf_efficientnet_b1.in1k_ft_df20_299
# hywu/Camelidae-8x7B
# User1115/whisper-large-v2-Biology-Fine-tuning-mul-500steps
# FINISHED MODEL PORTION
# OALL/details_airev-ai__Jais-Inception-7b-V0.2
# 1231czx/gemma2b_sft_collected_math
# open-llm-leaderboard-old/details_Locutusque__gpt2-conversational-or-qa
# open-llm-leaderboard-old/details_genaicore3434__Mistral-7b-instruct-v0.2-summ-sft-lp-e1
# BEE-spoke-data/yahoo_answers_topics-long-text
# TIRData/math_stage2_middle_2
# pankajmathur/alpaca_orca
# open-llm-leaderboard-old/details_jondurbin__airoboros-13b-gpt4-1.2
# open-llm-leaderboard/apple__DCLM-7B-details
# joey234/mmlu-college_chemistry-dev
# open-llm-leaderboard-old/details_TheBloke__Wizard-Vicuna-7B-Uncensored-HF
# open-llm-leaderboard-old/details_SF-Foundation__Ein-72B-v0.12
# open-llm-leaderboard-old/details_Linly-AI__Chinese-LLaMA-2-7B-hf
# open-llm-leaderboard-old/details_cloudyu__Venus_DPO_50
# open-llm-leaderboard/PJMixers__LLaMa-3-CursedStock-v2.0-8B-details
# open-llm-leaderboard/mlabonne__phixtral-2x2_8-details
# open-llm-leaderboard-old/details_GeneZC__MiniChat-3B
# Boliang/math_rephrased_processed_dataset
# mxeval/mxeval
# GangCaoLab/Multi-FISH_ASFV
# open-llm-leaderboard-old/details_andysalerno__rainbowfish-7B-v9
# open-llm-leaderboard-old/details_beberik__rawr
# shuyuej/French-MMLU-College-Biology-Benchmark
# open-llm-leaderboard-old/details_chatty123__mistral_rank32_dpo
# open-llm-leaderboard-old/details_nicholasKluge__Aira-2-124M
# open-llm-leaderboard-old/details_openchat__openchat_v3.2
# open-llm-leaderboard-old/details_Walmart-the-bag__Yi-6B-Infinity-Chat
# open-llm-leaderboard-old/details_Sao10K__Euryale-1.3-L2-70B
# open-llm-leaderboard-old/details_OpenBuddy__openbuddy-mixtral-7bx8-v17.1-32k
# open-llm-leaderboard-old/details_mncai__agiin-13.6B-v0.1
# A2H0H0R1/Animal-nutrition
# scikit-fingerprints/MoleculeNet_HIV
# sulovexin/my_test_dataset
# open-llm-leaderboard-old/details_adamo1139__Yi-34B-200K-AEZAKMI-RAW-1701
# HydraLM/chemistry_dataset_standardized
# open-llm-leaderboard-old/details_NeuralNovel__Pigris-7b-v0.3
# open-llm-leaderboard-old/details_Technoculture__Medorca-4x7b
# open-llm-leaderboard/Alibaba-NLP__gte-Qwen2-7B-instruct-details
# open-llm-leaderboard/johnsutor__Llama-3-8B-Instruct_ties-density-0.3-details
# OALL/details_Ali-C137__Q2AW1M-0010
# open-llm-leaderboard-old/details_logicker__SkkuDS-DPO-72B-v3
# open-llm-leaderboard/altomek__YiSM-34B-0rn-details
# open-llm-leaderboard-old/details_kekmodel__StopCarbon-10.7B-v4
# open-llm-leaderboard-old/details_TheBloke__guanaco-13B-HF
# joey234/mmlu-conceptual_physics-neg-prepend-verbal
# OALL/details_tenyx__Llama3-TenyxChat-70B
# hyf015/EgoExoLearn
# open-llm-leaderboard-old/details_nisten__bigdoc-c34b-instruct-tf32
# open-llm-leaderboard/netcat420__MFANN3bv0.19-details
# OALL/details_mmnga__Llama-3-70B-japanese-suzume-vector-v0.1
# kenhktsui/basemath
# open-llm-leaderboard-old/details_Kukedlc__NeuralKrishna-7B-V2-DPO
# open-llm-leaderboard-old/details_psmathur__model_101
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-6c03d1-1913164906
# open-llm-leaderboard-old/details_rwitz__dec10
# open-llm-leaderboard-old/details_CalderaAI__13B-BlueMethod
# OALL/details_GritLM__GritLM-8x7B-KTO
# HeshamHaroon/Arabic_prompts_Mini_175
# open-llm-leaderboard-old/details_gmonsoon__MiniCPM-2B-Base-v2
# open-llm-leaderboard-old/details_Gryphe__MythoLogic-13b
# open-llm-leaderboard-old/details_Minami-su__Qwen1.5-0.5B-Chat_llamafy
# open-llm-leaderboard-old/details_shahzebnaveed__StarlingHermes-2.5-Mistral-7B-slerp
# weihao1/MuMath-Data
# open-llm-leaderboard-old/details_nlpguy__StarFusion-alpha1
# sparsh35/aops
# sr5434/CodegebraGPT_data
# mesolitica/translated-competition_math
# open-llm-leaderboard/Qwen__Qwen1.5-7B-Chat-details
# open-llm-leaderboard-old/details_SanjiWatsuki__Loyal-Toppy-Bruins-Maid-7B-DARE
# open-llm-leaderboard-old/details_bofenghuang__vigogne-2-7b-instruct
# open-llm-leaderboard-old/details_TeeZee__Buttocks-7B-v1.1
# open-llm-leaderboard-old/details_decem__Dionysus-Mistral-n1-v1
# open-llm-leaderboard-old/details_conceptofmind__Hermes-LLongMA-2-7b-8k
# open-llm-leaderboard-old/details_indischepartij__OpenMia-Indo-Mistral-7b-v3-refined
# allenai/math_qa
# open-llm-leaderboard-old/details_Weyaxi__OpenHermes-2.5-neural-chat-v3-3-openchat-3.5-1210-Slerp
# open-llm-leaderboard-old/details_sethuiyer__SynthIQ-7b
# open-llm-leaderboard/paloalma__ECE-TW3-JRGL-V1-details
# open-llm-leaderboard-old/details_icefog72__WestIceLemonTeaRP-32k-7b
# open-llm-leaderboard-old/details_ddyuudd__mistral_dmbr03_32_sig
# open-llm-leaderboard-old/details_Mikivis__gpt2-large-lora-sft1
# open-llm-leaderboard-old/details_TinyLlama__TinyLlama-1.1B-intermediate-step-1195k-token-2.5T
# Ekimetrics/climateqa-ipcc-ipbes-reports-1.0
# open-llm-leaderboard-old/details_MiniMoog__Mergerix-7b-v0.2
# open-llm-leaderboard/BEE-spoke-data__smol_llama-101M-GQA-details
# open-llm-leaderboard-old/details_ToastyPigeon__smolphin-test-bottomheavy
# openclimatefix/gfs-surface-pressure-0.5deg
# pszemraj/goodreads-bookgenres
# open-llm-leaderboard-old/details_cognitivecomputations__dolphin-2.8-experiment26-7b
# open-llm-leaderboard-old/details_Xenon1__Xenon-1
# open-llm-leaderboard-old/details_freecs__Zero-7B-test-1
# OALL/details_2A2I-R__L100MT
# open-llm-leaderboard-old/details_abhinand__gemma-2b-tamil
# VTaPo/mulchoice_math
# open-llm-leaderboard-old/details_CausalLM__7B
# pkking/testnnmm
# 1231czx/math_stage2_hard2_5
# TIRData/math_stage1_7
# open-llm-leaderboard-old/details_jzjiao__opt-1.3b-rlhf
# nguyentruong-ins/nhlcoding_question_bank
# math-eval/TAL-SCQ5K
# open-llm-leaderboard-old/details_NousResearch__Nous-Hermes-2-Mistral-7B-DPO
# AndrewZeng/metamath_trn_query_part_1
# open-llm-leaderboard-old/details_haoranxu__ALMA-7B
# open-llm-leaderboard-old/details_macadeliccc__piccolo-math-2x7b
# open-llm-leaderboard/HuggingFaceH4__zephyr-7b-alpha-details
# open-llm-leaderboard-old/details_NYTK__PULI-GPTrio
# open-llm-leaderboard-old/details_Eric111__UltraCatunaMayo
# open-llm-leaderboard-old/details_PygmalionAI__pygmalion-1.3b
# wanderkid/UniMER_Dataset
# cminja/ds-math-ms
# open-llm-leaderboard-old/details_Sao10K__Stheno-1.2-L2-13B
# mathemakitten/winobias_antistereotype_test
# open-llm-leaderboard-old/details_SilverCoder66__Mistral-7B-Instruct-adapt-v0.21
# open-llm-leaderboard-old/details_PulsarAI__GenAI-Nova-13B
# FINISHED DATA PORTION
# github.com/bhanML/Co-teaching
# github.com/anuragranj/spynet
# github.com/GiuseppeLaurenza/I_F_Identifier
# github.com/minoTour/minoTour
# github.com/houchengbin/Fossil-Image-Identification
# github.com/phe-bioinformatics/snp-search.Operating
# github.com/Nirnai/DeepRL
# github.com/jgolbeck/fakenews
# github.com/MAIF/eurybia
# github.com/motahhir/MATLAB-Simulink-Model-of-Photovoltaic-Cell-Panel-and-Array-
# github.com/lizanafj/python_examples_with_NetCDF4_filesand
# github.com/vb690/approx_incentive_salience.Code
# github.com/pyro-ppl/numpyro
# github.com/seandavi/awesomesingle
# github.com/jvschroeder/OrdStat
# github.com/davidandym/multilingual-NER
# github.com/Lab513/DIY_Optogenetics
# github.com/rahulAgrBej/seafoodGDELT
# github.com/aspuru-guzik-group/selfies
# github.com/pdixonecon/MR_cancer_simulation
# github.com/shenyangHuang/TGB
# github.com/uoNuM/two-stream-gma
# github.com/run-youngjoo/SC-FEGAN
# github.com/ankidroid/Anki-Android
# github.com/anthropics/evals
# github.com/milc-qcd/
# github.com/kmtran95/Battery-HPPC-model-fitting
# github.com/s4hts/HTStream
# github.com/s4hts/HTStream
# github.com/s4hts/HTStream
# github.com/s4hts/HTStream
# github.com/cbaziotis/nmt-pretraining-objectives
# github.com/david-cortes/contextualbandits
# github.com/shanedenecke/ABC_scan
# github.com/liujia93/Scattering-matrix-for-loess-dust
# github.com/polymaths-lab/reaction-diffusion-flagella
# github.com/UVA-DSA/ContextSafetyMonitorAPS
# github.com/ThibaultLatrille/MutationSelectionDrift
# github.com/lilv98/ABIN
# github.com/Khasawneh-Lab/simple_pendulum
# github.com/eclipse/jetty.project15
# github.com/mlux86/acdc
# github.com/uber/react-digraph
# github.com/eyounx/VirtualTaobao
# github.com/francescopappalardo/ISPNAuthors'
# github.com/AaltoML/t-SVGP
# github.com/Sergey-St/richwolf
# github.com/JHnlp/BC5CIDTask
# github.com/nlesc-smcm/hymls
# github.com/RrZzZz/Bayesian-Semisupervised-learning-under-nonparanormality
# github.com/PIRCImagingTools/DINGO.git
# github.com/hyulab/NetFlow3D
# github.com/AmibethThompson/Oilseed-Rape-Shares-Pollinators
# github.com/jim-schwoebel/voicebook
# github.com/SignorLab/Flamenco_manuscript
# github.com/AsIsmail/Apple-Dataset
# github.com/biotea/biotea-annotation
# github.com/ag-gipp/chem_formula_extractor
# github.com/ihmwg/FLR-dictionary
# github.com/s-andrews/forkcall
# github.com/olegl/distort
# github.com/ntu-dasl-sg/dynamic-EV-forecasting
# github.com/keras-team/keras,\"
# github.com/zxlzr/UrbanWaterloggingInference
# github.com/wf4ever/ro-
# github.com/nicaless/fernn
# github.com/IBM/row-column-intersection
# github.com/bioinfoUQAM/Kevolve
# github.com/aliiasgharii/Data
# github.com/aurioldegbelo/3D4DT
# github.com/juliaromberg/cimt-argumentmining-dataset
# github.com/zli867/RxFireEmission
# github.com/google-research/deep_ope
# github.com/AlafateABULIMITI/politeness-detection
# github.com/trambakbanerjee/TRUH
# github.com/skissler/EZH2
# github.com/njacquie/TAT-Continued
# github.com/netneurolab/bazinet
# github.com/jcilwz/dRHP-GreyFun
# github.com/mnamysl/nat-acl2021
# github.com/LabWang307/Antimalarial_Mechanism_ART.Supplementary
# github.com/Isaac-a95/CachedFluxes
# github.com/mustafakarabag/SP-ADMM
# github.com/laibe/M2U-Net
# github.com/iai-group/DBpedia-Entity
# github.com/bretglun/fwqpbo,accessed
# github.com/MaimonLab/EyeTrackerForm
# github.com/Ye-D/Meteor
# github.com/awsm-research/AIBugHunter
# github.com/awsm-research/AIBugHunter
# github.com/stavros7167/distributed_protocol_completion
# github.com/ibartomeus/powerlines
# github.com/Boyden/Pretreatment-Prediction-to
# github.com/InsaneLife/ChineseNLPCorpus
# github.com/takedarts/swgridnet
# github.com/matthewcoole/Semantic
# github.com/PlanTL-SANIDAD/PharmaCoNER-CODALAB-In
# github.com/fraimondo/cudaica
# github.com/dheeraj7596/CONDA
# github.com/ps02v/HoloArt
# github.com/paulmtree/Lung-
# github.com/dattalab/kinect2nidaq
# github.com/urmi-21/orfipy.Installation:
# github.com/qmeng99/Multiview-Motion-Estimation-for-3Dcardiac-motion-tracking
# github.com/lzaramela/SynDNA
# github.com/RabadanLab/PH_recombination_virus
# github.com/ehiggs/spark-terasort
# github.com/RobinVanSchendel/SIQ
# github.com/USGS-Astrogeology/usgscsm>
# github.com/neavemj/microbiomeMap
# github.com/hybridlca/pyspa
# github.com/beyondpie/CEMBA_wmb_snATAC
# github.com/royg27/PAG-ROB
# github.com/JX-Zhong/KLZ_AS_analysis
# github.com/varun-nagaraja/BING-Objectness
# github.com/icsharpcode/ILSpy
# github.com/LANL-Bioinformatics/FaQCsAnnotation
# github.com/cjneely10/EukMetaSanity
# github.com/eiset/Review-of-infectious-diseases-in-refugees-and-asylum-seekers.gitAuthors'
# github.com/kathoffman/steroids-trial-emulation
# github.com/MIT-LCP/mimic-code
# github.com/MIT-LCP/mimic-code
# github.com/MIT-LCP/mimic-code
# github.com/MIT-LCP/mimic-code
# github.com/MIT-LCP/mimic-code
# github.com/energy-modelling-toolkit/Disp
# github.com/BIIG-UC3M/IGT-UltrARsound
# github.com/scikit-geometry/scikit-geometry.5
# github.com/vmerel/Dsu-TE
# github.com/UBrau/ModelPerformance
# github.com/mattianeroni/AntColony
# github.com/Jacob-Skov/DTSM-SOFR-Futures
# github.com/NLAndreas/Dynamic_MCC.git
# github.com/s-meaden/Meaden_CB_2021
# github.com/gcappon/replay-bg.Significance:
# github.com/abhilashlakshman/ethoscopeCodes_eLife
# github.com/cweitkamp3/Distribution-of-Distances
# github.com/geovista/GeoCorpora
# github.com/nitadori/Hermite
# github.com/ComplexityBiosystems/Flat_
# github.com/danieldk/sticker
# github.com/UMCUGenetics/Mutational
# github.com/ipa320/weiss_kms40
# github.com/alisonbma/aiSFX
# github.com/hk1785/OMiSA
# github.com/HKUST-KnowComp/R-Net
# github.com/RGellerLab/CVB3_
# github.com/pratas/goose
# github.com/braunefe/BWEeval
# github.com/SFB-ELAINE/SI_Staehlke_MDPI_Cells
# github.com/chopdgd/CHOP_CancerPanel_Analysis
# github.com/jrobine/smaller-world-modelsDeclarations
# github.com/w2kun/RNW
# github.com/staplesinLA/denoising
# github.com/WhirlFirst/somde
# github.com/jbpeace/E2ETag
# github.com/ryukenzen/360action
# github.com/andykin888/GT-predict-refugee-flows.git.FundingOpen
# github.com/joelarrais/hydra
# github.com/Fruktus/CloudPredictionFramework
# github.com/serg-ml4se-2019/group6-code-completion
# github.com/gomohler/pnas2020.y1To
# github.com/danieldk/tinyest
# github.com/biotite-dev/biotite
# github.com/ariercole/Cambridge_
# github.com/HuiZhangDB/PMEmo
# github.com/Aphoh/temp_
# github.com/ETHZ-INS/DLCAnalyzer
# github.com/peterthorpe5/intergenic_regions
# github.com/2dot71mily/uspec.From
# github.com/GaoLabXDU/STDecompositionAdjustment
# github.com/mathabaws/SOTA_
# github.com/Magdoll/ANGEL
# github.com/gdesvignes/pyfitorbit
# github.com/yewzz/SIL
# github.com/wyu54/many-body-force-inferSupplementary
# github.com/slundqui/TFSparseCode
# github.com/computationalmedia/supmmd
# github.com/hannahgz/BenchmarkRCStrategies
# github.com/gjy3035/NWPU-Crowd-Sample-Code-for-Localization3
# github.com/openbox-bio/ebola_i2o
# github.com/yihui-he/TSP
# github.com/sfu-dis/ermia
# github.com/HIPS/autograd
# github.com/MASILab/masimrs
# github.com/Ksieber/piccolo
# github.com/lbolla/EMpy
# github.com/omerfaruktuna/squeezedmodels
# github.com/khanrc/tf
# github.com/AMIGA-IAA/hcg_hi_pipeline
# github.com/ednieuw/ELISA-logit-regression
# github.com/jenfb/bkmr
# github.com/BioX-NKU/scButterfly_source68.To
# github.com/CARV-ICS-FORTH/frisbee
# github.com/kaiekubjas/3D-genome-reconstruction-frompartially-phased-HiC-data.This
# github.com/coli-saar/Syntax-COGS
# github.com/sgdgp/VirtualHome_IRL
# github.com/dashishi/LDPolypVideo-Benchmark
# github.com/ninglab/SiamCDR
# github.com/rktamplayo/CHIM
# github.com/willov/alcohol_appwith
# github.com/Jia-Research-Lab/JigsawClustering
# github.com/desertfireballnetwork/DFN_darkflight
# github.com/derekchuank/high-
# github.com/samuellab/mindcontrol-analysis
# github.com/korenana/oxybeatdataset
# github.com/mauriceqch/pcc_geo_cnn_v2
# github.com/kolosovpetro/Mathematica-script
# github.com/reineking/pyds
# github.com/mneunhoe/simloglm.We
# github.com/engranaabubakar/dpdk-advance-scanner
# github.com/Hollenbach-lab/C4Investigator
# github.com/gzanella/barker
# github.com/PredictiveIntelligenceLab/CausalPINNs
# github.com/nspunn1993/BT-Unet
# github.com/jin-choo/persistence
# github.com/HP-CAO/6IMPOSE
# github.com/LaurieLecomte/SNPs_indels_SR
# github.com/sorgenfrei-c95/qsoMLdiffcurves
# github.com/trinityrnaseq/trinityrnaseq
# github.com/trinityrnaseq/trinityrnaseq
# github.com/trinityrnaseq/trinityrnaseq
# github.com/trinityrnaseq/trinityrnaseq
# github.com/trinityrnaseq/trinityrnaseq
# github.com/trinityrnaseq/trinityrnaseq
# github.com/trinityrnaseq/trinityrnaseq
# github.com/trinityrnaseq/trinityrnaseq
# github.com/DominicSicilian/XZ
# github.com/gamlj/gamlj
# github.com/SophiaRauh/fr_de_
# github.com/TeamSundar/dNNDR-featx
# github.com/Introvertuoso/BrainTargeting
# github.com/karllark/fuv
# github.com/nick-bailey/Poverty-and-private-renting
# github.com/dima42/uber-gps-analysis
# github.com/jdmanzur/ml4aml
# github.com/YuanGongND/ast
# github.com/alexpghayes/netmediate
# github.com/igrahek/ControlAdjustmentCosts.git
# github.com/ShiftingSubspace/shiftsubs
# github.com/locuslab/tta_conjugate
# github.com/Atomu2014/product-nets-distributed18
# github.com/adamginsburg/W51_ALMA_2013.1.00308.S
# github.com/wangzhaoyu07/PP-CSAfor
# github.com/xjtu-omics/SARS-CoV-2_graph_genome
# github.com/HanbyolJang/LDR-HDR-pair_Dataset
# github.com/DICP1810/ComMap
# github.com/covid19india/data
# github.com/topics/motion-blur
# github.com/oneal2000/Wikiformer
# github.com/gan-orlab/MIPVar
# github.com/UrbanNet-Lab/scaling_in_
# github.com/csijcs/snakepipes
# github.com/CSCSI/Triana
# github.com/esteinig/sccion
# github.com/automated-ultramicrotomy/crosshair
# github.com/korcsmarosgroup/SalmoNet2
# github.com/paprikachan/DeepMF
# github.com/MichalBusta/DeepTextSpotter
# github.com/eivindmoholdt/Master-Code.git
# github.com/DonsetPG/narya
# github.com/TJPaik/InvariantRepresentation
# github.com/phillips-lab/SLP
# github.com/fritzsedlazeck/SURVIVOR
# github.com/fritzsedlazeck/SURVIVOR
# github.com/carlthome/python-audio-effects
# github.com/sabbas123/ArSL-video-corpus-6.git
# github.com/ZurichNLP/coverage-contrastiveconditioning
# github.com/hlwang1124/wheelchair-dataset.git
# github.com/Kali-Hac/SM-SGE
# github.com/GlobalSharkMovement/GlobalSpatialRisk
# github.com/gist-ailab/teaching-where-to-look
# github.com/tseemann/abricate
# github.com/alexanderlerch/pyACA
# github.com/seqan/flexbar
# github.com/seqan/flexbar
# github.com/sigven/cpsr
# github.com/GalacticDynamics-Oxford/AGAMA
# github.com/dchooper/class
# github.com/microsoft/SimMIMdefault
# github.com/lulsheng/CBCE-Net
# github.com/ShuaihuaGao/HDXcode
# github.com/SelimHorri/ecommerce-microservice-backend-app
# github.com/loiclec/fuzzcheck-rs
# github.com/Hxyou/IdealGPT
# github.com/willferreira/mscproject
# github.com/mrc-ide/sircovid
# github.com/Smerity/keras_snli
# github.com/see-mike-out/erie-chrome-ext
# github.com/efficient/mica
# github.com/astrostat/pylira.It
# github.com/rbr1/Immune_receptor_NETWORK-GENERATIONAdditional
# github.com/cat-loves-donuts/ImmuNetNAS
# github.com/haped/solarv
# github.com/dvamossy/EmTract
# github.com/Ks1997cris/CD47-SIRP
# github.com/smimram/catt
# github.com/shuifeng1988/Bats_echolocation_
# github.com/eBioKit/tutorials
# github.com/ErikHartman/2020-peptidomics
# github.com/AlexWixom/Transcriptome_scripts
# github.com/EttusResearch/gr-
# github.com/AndreasRupp/ecdf
# github.com/liuyu-star/drMARS
# github.com/GradoZeroTeam/IAMRRI
# github.com/wokast/PyCactus
# github.com/locuslab/deq-ddim
# github.com/aghie/disco2labels
# github.com/psychbruce/bruceR
# github.com/hadley/reshape,accessed
# github.com/dannyneil/public_plstm
# github.com/slackhq/nebula
# github.com/kouzheng/CovPred-FL
# github.com/bit-bots/bitbots_behavior
# github.com/chriskal96/physics-theory-citation-network
# github.com/microsoft/farmvibes-ai
# github.com/orhungorkem/IPDwithTolerance
# github.com/kevjin/rce-research
# github.com/NileTMRG/NileULex
# github.com/gtStyLab/lk-dfba
# github.com/oxford-pharmacoepi/CovidVaccinationSafetyStudy_neuroimmune
# github.com/LTeinturier/Cloud-Killer-
# github.com/maciejkula/binge
# github.com/ifrz/Home-Automation---
# github.com/Bayer-Group/xsmiles-use-cases.In
# github.com/kuku-sichuan/ComparisonDetector
# github.com/gw17/sltu_
# github.com/CodeSubmission642/Wate
# github.com/mala-lab/SIC-CADS
# github.com/webis-de/summary-explorer
# github.com/brave/browser-
# github.com/BiocomputeLab/mctools
# github.com/GeminiDRSoftware/GHOSTDR.While
# github.com/cjurban/DeepConfirmatoryIFA
# github.com/farhat-lab/fast-lineage
# github.com/Orange-Opensource/metamorphosed.metA-MoRphosED
# github.com/FaridYusifli/MKGDB
# github.com/icecube/PSLab_PS_analysis
# github.com/jameszhou-gl/CBRE
# github.com/melonheader/Stability
# github.com/common-workflow-lab/cwljava
# github.com/drizopoulos/GLMMadaptive2021
# github.com/elifesciences-publications/hpo_ova_eggL_screen
# github.com/TaherehMahmoudi/OCT-CVI-DeepLearning
# github.com/ramonsanabria/insights_2021
# github.com/just-ananonymous-github-account/cvpr
# github.com/MikeRollins-Green/CODA-PGX.Author
# github.com/TheEconomist/covid-19-excess-deaths-tracker
# github.com/cnsetzer/Setzer2022_BNSpopkNe.bound
# github.com/PeterSarkies-LMS/TEMALs_repo
# github.com/therimalaya/03-prediction-comparison
# github.com/gbrammer/unicorn
# github.com/cvg/DeepLSD
# github.com/meta-logic/sequoia
# github.com/CorCenCC/CyTag
# github.com/aaronrkaufman/compactness
# github.com/torbjone/sharp_wave_ripples
# github.com/mischn-dev/popRR.git
# github.com/breze-no-salt/breze
# github.com/dynamicslab/Saddle-Mediated-Transport-of-Double-Pendulum
# github.com/josef0731/CDSMutSig
# github.com/lambdaloop/anipose
# github.com/npellet/visualizer]
# github.com/JohnLangford/vowpal_wabbit
# github.com/kerkelae/dkmri
# github.com/nhs-bnssg-analytics/covid-simr-hospital-application
# github.com/Herodot1/FociDetect_Training
# github.com/SamsungLabs/MotionID
# github.com/szgy66/Vessel-Segmentation-of-photoacoustic-imaging
# github.com/WAFI-CNR/ddna-toolbox
# github.com/avillago/LEnormalSpace
# github.com/thanhnguyentang/pib
# github.com/bscoventry/OpticalTCNeuromodulation
# github.com/daokunzhang/HSCA
# github.com/clbenoit/CutOneStrand.This
# github.com/dash-ka/REAL-BioCR
# github.com/bienflorencia/rBiodiversidata
# github.com/bienflorencia/rBiodiversidata
# github.com/mae92/MutantHuntWGS.KEYWORDSMutant
# github.com/Eric9906/JPEGImages
# github.com/IPCO-Rlibrary/IPCO
# github.com/cmavian/HIV-Florida-paper
# github.com/ShadeLab/Paper_Chodkowski
# github.com/YushuShi/MicrobiomeCluster
# github.com/warewulf/warewulf3
# github.com/choderalab/rbd-ab-contact-analysis
# github.com/roryk/DEXSeq
# github.com/bchangala/nitrogen,\"
# github.com/clowee/OSS-PESTO
# github.com/ldgh/NAToRASimulator
# github.com/nanoporetech/modkit
# github.com/nanoporetech/modkit
# github.com/nanoporetech/modkit
# github.com/nanoporetech/modkit
# github.com/Kirikaku/LawStats
# github.com/Tribler/py-ipv8
# github.com/andreasveit/coco-text
# github.com/almadana/alle.covid
# github.com/arpg/kf
# github.com/RPi-Distro/firmware-
# github.com/vressegu/LU_SALT_SelfSim
# github.com/hou-yz/MVSelect
# github.com/anubhavparas/quadrotor_control_ppo
# github.com/davidsandberg/f
# github.com/Nemocas/AbstractAlgebra.jl
# github.com/BobYHY/CAPE.Considering
# github.com/NoonanM/ctpm
# github.com/LarsVogt/Knowledge-Graph-Building-Blocks
# github.com/cinserra/4OPS.Any
# github.com/rumenzu/quartz
# github.com/HUSTNLP-codes/GRT
# github.com/EngAAlex/VAIM
# github.com/SnorkerHeng/PLD-UAV
# github.com/SonjaKrai/PopularRankingsExampl
# github.com/dlouk/mvsa-pce
# github.com/STOmics/SAW.Notably
# github.com/BgeeDB/IQRray
# github.com/iwbailey/processRFmatlab
# github.com/pinouche/attention-MIR
# github.com/UditSinghParihar/RoRD
# github.com/LBC-Iriarte/Shewanella_
# github.com/olgapelloni/subword_evenness
# github.com/jarny/biopyramid
# github.com/echen102/covid-19-tweetids
# github.com/katharinakohls/VerLoc
# github.com/GiovannaNicora/hepar
# github.com/pablosanchezmart/Sanchez-Martinez_etal-2022.For
# github.com/khnshn/interaction-styles-evaluation.The
# github.com/opendaylight/yangtools
# github.com/jrosebr/imutil
# github.com/google/s2geometry
# github.com/zhuyitan/IGTD
# github.com/sweetiek/Broiler_ileum_astaxanthin
# github.com/willwhitney/reprieve
# github.com/richteague/eddy.APPENDIX
# github.com/researchmm/DBTNet
# github.com/l294265421/AC-MIMLLN
# github.com/jdebruyn/BDM-Microbiology.Fluorescence
# github.com/gangwug/LTMR
# github.com/CSIRO-Acoustics/IMOS-Bioacoustics
# github.com/angelosalatino/cso-classifier
# github.com/jnirody/invertICPs
# github.com/Yruikk/DKPCA-ADMM
# github.com/HBossier/BigDataPIM
# github.com/openai/gpt-2.tial
# github.com/madeleine-mckenzie/REvIEW
# github.com/sct-pipeline/ukbiobank-spinalcord-csa
# github.com/addtt/attend-infer-repeat-pytorchfor
# github.com/leggedrobotics/anomaly
# github.com/nvpatin/Amplicon-visualizations
# github.com/argonne-lcf/PythonFOAM
# github.com/hypaik/HCUPSIDCA_trajectory_tracking
# github.com/rajewsky-lab/mirdeep2,accessed
# github.com/AlisonMcAfee/test
# github.com/GLOW-deep/GLOW
# github.com/moleibobliu/Maxway_CRT
# github.com/lucasmansilla/ACRN_Chest_X-ray_IA
# github.com/CoDEresearchlab/Meta_analysis_NDDs_DICCs
# github.com/yaoyao-liu/classincremental-learning
# github.com/mdurandruel/grippertask.matrix
# github.com/marcelTBI/CNV_data
# github.com/151140043/Sem2022task8.git
# github.com/yangfurong/X-Fi-code
# github.com/hguenther/smtlib2
# github.com/epochx/PEER
# github.com/merrillrudd/LIME
# github.com/raaslab/resilient_target_tracking.git
# github.com/msiebert1/UCSC_spectral_
# github.com/Reb08/T2DB
# github.com/mekise/graph-theory-dda
# github.com/camoragaq/BrumiR.Personal
# github.com/trustyuri/trustyuri-python
# github.com/karchinlab/clump
# github.com/g0v/moedict-data
# github.com/masonng-astro/nicerpy
# github.com/felherc/MAESTRO_MO
# github.com/s41m0n/opportunistic_monitoring
# github.com/Ling-CF/PPNV2.Index
# github.com/snastase/narratives
# github.com/simonmape/minibatch-ABC
# github.com/yx299/stratification
# github.com/TIO-IKIM/CellViT
# github.com/dgg32/maxbin2_checkm_slurm_illumina
# github.com/Henningston/MLoptABM
# github.com/DepMap-Analytics/CoRe
# github.com/DepMap-Analytics/CoRe
# github.com/DepMap-Analytics/CoRe
# github.com/dkesada/Class-DBN
# github.com/Soumyabrata/weather-features
# github.com/keyakkie/coarse-tuning
# github.com/bertis-informatics/deep-mrm
# github.com/artempankin/korffgroup
# github.com/CDDLeiden/QSPRPred
# github.com/Beomi/KcBERT
# github.com/jonguo111/Rail_components_image_data.git
# github.com/GSEA-MSigDB/GSEA_R
# github.com/hapi-server/data-specification
# github.com/kmaag/Temporal-False-Negative-Reduction
# github.com/caelan/stripstream
# github.com/adamhbroad/single_cell_intestine
# github.com/PDBeurope/pdb-images
# github.com/Zongrui-Dai/Kernel-lasso-feature-expansion
# github.com/aminshabani/extreme-indoor-sfm
# github.com/jokofa/JAMPR_plus
# github.com/dpeerlab/ArchR.Author
# github.com/zhiqiangzhongddu/SELENE
# github.com/Haokai-Tian/Tian2022_microbiome.git
# github.com/Rdatatable/data.table
# github.com/ZJU-FAST-Lab/VID-Fusion
# github.com/dmattie/aircrush
# github.com/tristen/tablesort
# github.com/taodav/nsrs
# github.com/samlo777/cf-seq.git]
# github.com/Lakens/TOSTER
# github.com/dhawat/MCRPPy
# github.com/yzhao062/Pyod.IForest
# github.com/GuedemannLaura/POA-IV
# github.com/BrillouinMicroscopy/Bril-louinAcquisition
# github.com/PDBeurope/pdb-images#pdbimages
# github.com/canceromics/MeRIPsimulator[83]
# github.com/ZoulfikarShmayssani/Food-Exposure-Models
# github.com/EliaBisi/LocalMaps
# github.com/jokelley/deviltranscriptomics
# github.com/RichardsGroup/LSSTprep
# github.com/gpereyrairujo/IRimage
# github.com/joepickrell/1000-genomes
# github.com/clarinsi/SloSummarizer
# github.com/epfl-dlab/retweet-evolution
# github.com/WongKinYiu/yolov7
# github.com/lzx551402/contextdesc
# github.com/DITEP/DeepOS.The
# github.com/VIP-Group/TASER
# github.com/mb2019/Comorbidity-HMM
# github.com/sandialabs/Juxtaposer
# github.com/clovaai/webvicob
# github.com/borisrperezg/TDPaymentAndPreventivePractices-Protocol
# github.com/kuanweih/strong_lensing_vit_resnet
# github.com/MPR-UKD/CEST-Generator,last
# github.com/anhad13/SelfTrainingAndLRP
# github.com/EricFournier3/Python
# github.com/qiangchi/SSKD,accessed
# github.com/WimPouw/AirSacTracker
# github.com/dosreislab/bppr
# github.com/erinijapranckeviciene/galaxy-dnpatterntools
# github.com/jacobslab/Travelingwave-analysis
# github.com/Ziemnono/fenics-inverseFEM
# github.com/stat430dspm/plr
# github.com/water-mirror/NeuLNS
# github.com/poloclub/NeuroMapper
# github.com/syjya/Comer
# github.com/coongroup/LipiDex
# github.com/NVlabs/I2SB
# github.com/changsn/STViT-R
# github.com/philippeDG/VisiTherS
# github.com/sosnicklab/upside2-md
# github.com/fonglab/scaffold-heatmap-pub
# github.com/fonglab/scaffold-heatmap-pub
# github.com/evoml/evoml
# github.com/LSSTDESC/Requirements
# github.com/satijalab/seurat-wrappers
# github.com/yanzhu-ji/avian-msats
# github.com/DianaCarrera/rvclass
# github.com/apennisi/segnet
# github.com/swz30/MIRNetv2
# github.com/SanikaVT/Liver-disease-prediction
# github.com/cogsys-tuebingen/empirically_explaining_sgd_from_a_line_search_perspective
# github.com/syngenta/linchemin_services
# github.com/tatsu-lab/alpaca_
# github.com/Ttantto/wph_quijote
# github.com/BaiDingHub/ABP
# github.com/D3TaLES/databases_demo
# github.com/xukun01102021/cIGRN
# github.com/weiss19/AH-v-MH
# github.com/al-mcintyre/mCaller_analysis_scripts
# github.com/RexGLiu/HierPolicies
# github.com/jonatanalvelid/ImSwitch-etSTED
# github.com/StanfordASL/unbalanced-opf-toolkit
# github.com/seojksc/seojk-kuids
# github.com/bxclib2/kaggle_gender_coref
# github.com/fkie-cad/cve-attribution-s2
# github.com/nodrogluap/nybbler
# github.com/Cassie94/LST
# github.com/chycxyzd/LDFC.Author
# github.com/JordiBolibar/ALPGM.Competing
# github.com/semitrivial/ExtendedEnvironments
# github.com/Tencent/TscanCode
# github.com/ParmEd/ParmEd
# github.com/TeddyTuresky/BrainMorphometry_DiminishedGr
# github.com/tatsu-lab/stanford_alpaca.20:
# github.com/astromatic/swarp
# github.com/sudalvxin/2018-GSVT.git
# github.com/zlwang-cs/TransModality
# github.com/KatharinaGerstner/mobsim_app
# github.com/MatejUlcar/SloT
# github.com/prassepaul/mlmed
# github.com/soravux/scoop
# github.com/aozalevsky/alphafold2_vs_swissmodel.The
# github.com/zhangyichuan2002/PONE-D-24-17066.This
# github.com/martin-helmich/prometheus-nginxlog-exporter
# github.com/slisson/mps-richtext
# github.com/Aravinthck/Optimal-KCenters
# github.com/susannepinto/Quantile-Regression-CD
# github.com/theopolis/smc-fuzzer
# github.com/stephenslab/susieR
# github.com/jojobeck/fjordmelt.git
# github.com/etienne-monier/inpystem
# github.com/SIBECOL-Diversity-Inclusion/SIBECOL_
# github.com/SpoonLabs/sorald
# github.com/dhfbk/Detection-of-place-names-in-historical-travel-writings
# github.com/PhelypeOleinik/39803f2385a18d0e86dc3ff8fe02af7b
# github.com/emmakn/ReP
# github.com/ftudisco/SpectralClCoeff
# github.com/chiblya/scRNAseq_PG
# github.com/brainvisa/ana
# github.com/aeligulash/Long-term-outcomes-of-patients-with-COVID-19-withneurological-involvement
# github.com/marcomusy/pianoplayer
# github.com/cookpa/altAntsBrainExtraction
# github.com/bmazin/SDR
# github.com/neuronsson/CPF_COVID19_
# github.com/vkola-lab/azrt2021
# github.com/ndr09/VSRevo
# github.com/hui-tony-zk/PDclust
# github.com/XiaoChenPhD/Jia_2023
# github.com/cjshui/WAAL
# github.com/yinziqiao/DReSS-package
# github.com/ddiazdom/grlBWT
# github.com/ddiazdom/grlBWT
# github.com/josebmera/scabbard
# github.com/phenoscape/ontotrace
# github.com/CoronaNetDataScience/corona_index.Conflicts
# github.com/ComparativeGenomicsToolkit/cactus
# github.com/ftelschow/HermiteProjector
# github.com/YosukeHiguchi/espnet
# github.com/crickbabs/BABS-RNASeq.git
# github.com/the-benchmarker/graphql-benchmarks
# github.com/YanglanOu/patcher.git
# github.com/leeds-indoor-air/Touch_transfer_experiment_data_analysis.git
# github.com/elifesciences-publications/CRISPR_recorders_sims
# github.com/abolfazlsafikhani/SBDetection
# github.com/a9w/Fat2_
# github.com/digitalepidemiologylab/covid-twitter-bert
# github.com/mcdermatt/ICET
# github.com/TechnionTDK/efficient-td-enum
# github.com/danielstrombom/Asynchrony
# github.com/s3prl/LibriMix
# github.com/OlgaPerski/EMA_smoking_lapse_review
# github.com/OlgaPerski/EMA_smoking_lapse_review
# github.com/VarioML/VarioML
# github.com/ryanlunn/CanadaGooseLightAvoidance.git-Lunn
# github.com/mccullaghlab/IS-SPAQ.git
# github.com/ameliajimenez/curriculum-federated-learning
# github.com/andimarafioti/phaseRetrievalEvaluation
# github.com/XifengGuo/DEC-keras
# github.com/MoisesExpositoAlonso/napspg
# github.com/esha-banerjee/Hindi_Au-ToBI
# github.com/fallow24/SphereTDP
# github.com/Russel88/CRISPRCasTyper
# github.com/cherrihsu/asymmetrycells
# github.com/ivalab/Benchmarking_SLAM
# github.com/mattjj/svae
# github.com/peewpw/Invoke-PSImagefor
# github.com/frankschindler/OptimizedTensorContraction
# github.com/jaideep777/jaideep_thesis_videos
# github.com/MSBradshaw/LichenBarcod
# github.com/martinjzhang/AMT
# github.com/akamah/sst-isabelle.This
# github.com/luslab/psiclip
# github.com/sanger-pathogens/circlatorgEVAL
# github.com/yubowen-ph/JointER
# github.com/marcinabram/topological_transitions.second
# github.com/mkearney/rreddit
# github.com/yaohungt/Barlow-Twins-HSIC
# github.com/lwachowiak/ISCMs
# github.com/abdul-rasool/Improved-machine-learning-based-Predicti
# github.com/huggingface/distil-whisper
# github.com/scikit-multiflow/scikit-multiflow
# github.com/arces-wot/SEPA
# github.com/arces-wot/SEPA
# github.com/arces-wot/SEPA
# github.com/cherrymaryma/ARGs-in-drinking-water.Authors'
# github.com/xptree/LightNE
# github.com/Montmorency/imeall
# github.com/jellevos/threshold-multiparty-psi
# github.com/Jarmill/quantized_ddc
# github.com/ondovb/nCloze
# github.com/waldronlab/SingleCellMultiModal
# github.com/stepien-lab/MidgePy
# github.com/DSThayer/gp-coverage-tool
# github.com/lda-project/lda
# github.com/KIT-IAI/transformer-training-strategies.Author's
# github.com/nicolasJouvin/FisherEM
# github.com/linnarsson-lab/loompyfgsea
# github.com/jzlei/scEntropy
# github.com/ACEsuit/ACE.jl
# github.com/clearpathrobotics/spot
# github.com/KorAP/KorAP-XML-Krill#aboutkorap-xml
# github.com/telatin/BamToCov
# github.com/Wolfson-PNU-QMUL/PD_FBC
# github.com/alife-data-standards/converters-mabe
# github.com/spmallick/learnopencv
# github.com/maplesword/TOMRwModule
# github.com/biomedicalcybernetics/projection-separability-indices
# github.com/causal-rl-anonymous/causal-rl
# github.com/danielballan/jupyterhub-share-link
# github.com/mahiluthra/cognitionpatchiness
# github.com/phngs/allestm
# github.com/lakinsm/amrplusplus-shiny
# github.com/BarakGahtan/5GIRE
# github.com/meelgroup/ganak
# github.com/nljubesi/hr500k
# github.com/EBI-IntAct/IntactApp
# github.com/WujiangXu/NMCDRR
# github.com/WangYueFt/rfs
# github.com/Dynatrace/OneAgent-SDK-for-C
# github.com/heligone/spinorialBall
# github.com/yeerwen/UniSeg
# github.com/alexherbig/MultiVCFAnalyzer
# github.com/andreiarusoaie/certifying-unification-in-aml
# github.com/soskek/bookcorpu
# github.com/kanchukaitis/vsm.The
# github.com/rezacsedu/XAI
# github.com/IVSilverman/RAS_Sim
# github.com/CristianChadwick/WmFGN
# github.com/ucbvislab/p2fa-vislab
# github.com/adaptivegenome/repeatseq
# github.com/ScottLabUCB/HRTEM-Receptive-Field
# github.com/lspatial/autoresnetR
# github.com/connor-duffin/sswe
# github.com/hunkim/word-rnn-tensorflow
# github.com/HZhongLab/SI_View
# github.com/janinad88/ambrosia-beetle-fungus-farming
# github.com/yuxi6842/CRVAE
# github.com/Sorennorge/Day_night_
# github.com/y-nam/QFT
# github.com/leolani/cltl-diary-parent
# github.com/realwecan/mju-waste
# github.com/jcrvz/customhys.git
# github.com/Maggi-Chen/FusionSeeker
# github.com/argrecsys/argael
# github.com/0oshowero0/GEMS
# github.com/izycheva/pine
# github.com/Bhavna-R/DeepLearningQuantAnalysActinMicroridges
# github.com/istoilkovska/syncTA
# github.com/xia-lab/Microbiome
# github.com/forlilab/Meeko
# github.com/forlilab/Meeko
# github.com/BHFDSC/CCU003_01
# github.com/shalini1194/MOOC
# github.com/ml-jku/hopfield-layers
# github.com/Teoroo-CMC/PiNN
# github.com/neurodata/neuroparc.Resultsatlases.Through
# github.com/Crespo-Otero-group/fromage
# github.com/AntoniaMarcu/Data-Modification
# github.com/uf-hobiinformatics-lab/ADRD_risk_factor_knowledge_map
# github.com/YuePengUSTC/AADR
# github.com/desihub/fiberassign
# github.com/pwilmart/PAW_BLAST
# github.com/leiferlab/dualmag-analysis
# github.com/cbgethz/pancancer-clustering
# github.com/jiangj-niaid/EPI
# github.com/google-research-datasets/boolean-questions,7
# github.com/CoFiF/Corpus
# github.com/zubata88/mdgru
# github.com/mqbssppe/growthPhaseMCMC
# github.com/zeyun-zhong/AFFT?
# github.com/joaoascensao/S-L-REL606-BarSeq.FundingOpen
# github.com/jaimebaldeon/FNS-2020.Related
# github.com/andy840314/QANet-pytorch-7
# github.com/hansen7/LearnFairMetric_Empirical
# github.com/bw9bj/sRNA-Effector.Any
# github.com/KatherLab/preProcessing.All
# github.com/gbeiner/Counterexample-To-Symmetry-of-Lp-Norms-of-Eigenfunctions
# github.com/jli0117/ehrMGAN
# github.com/jonazhu/craspedacustasampling.Funding:
# github.com/sajjadium/OriginTracer
# github.com/bridgetbryan/work-loneliness-review.For
# github.com/AdRoll/rebar3_format
# github.com/xtensor-stack/xsimdnamespace
# github.com/jonascremer/chemotaxis_simulation
# github.com/CMASCenter/CARS
# github.com/jaburney/AgResilienceBrazil
# github.com/znes/OSeEM-SN
# github.com/onnx/tensorflow-onnx
# github.com/Mizuseki-Lab/microdrive
# github.com/bsdlab/Post-HocLabeling
# github.com/imfing/ava_
# github.com/mkhlgrv/investment_forecasting
# github.com/vklip/IOMK
# github.com/tingyaoyue/Dataset.git
# github.com/eleozzr/PRIME
# github.com/JiaXianYao/Bilateral-Texture-Filtering
# github.com/UniversalDependencies/tools.git
# github.com/nikolas-claussen/Geometric-control-of-Myosin-II-orientation-
# github.com/SBRG/MetPath
# github.com/DanieleFasano/Analytical_Kinks
# github.com/brunomnsilva/JavaFXSmartGraph
# github.com/haddocking/MemCplxDB
# github.com/PedestrianDynamics/VCNN4PuDe
# github.com/chz816/esacl
# github.com/tu-darmstadt-ros-pkg/hector_
# github.com/deepmind/dynamic-kanerva-machines
# github.com/chernzheng/nlpcc2023_shared_task7_ouchnai_
# github.com/viggin/domain-adaptation-
# github.com/tlacombe/homogeneousUROT
# github.com/synam/Ascon128a
# github.com/AtanasDRadkov/ChouLab_DMS
# github.com/jonassibbesen/vgrna-project-paper
# github.com/UcarLab/QuIN
# github.com/INCATools/intelligentconcept-assistant
# github.com/freetdi/tdlib
# github.com/ntnu-arl/ORACLEupon
# github.com/vharg/Bibli_Volc
# github.com/wzhings/antivaccine_detection
# github.com/peterson-tim-j/AWAPer
# github.com/revans011/classif
# github.com/stanfordnlp/edu-convokit?
# github.com/Jongchan/attention-moduleaccessed
# github.com/ohdsi-studies/MddAfterBbValidation
# github.com/gongbozhangpku/Good-Enough-Selection
# github.com/SandroLanfranco/endemics.git.Conflicts
# github.com/mtrimoska/EC-Index-Calculus-Benchmarks
# github.com/lindseylabrie/carp_eDNAfit
# github.com/ViniciusLima94/HMnetwork
# github.com/JianHPan/SilenceREIN
# github.com/JianHPan/SilenceREIN
# github.com/nuest/rodman
# github.com/SpectralPOD/spod_
# github.com/RIKENBCIL/MultimodalRigidTransform
# github.com/floriancafiero/nocomments
# github.com/samuelcajahuaringa/dCCIforLAMMPS
# github.com/shahed30/SeqToDNA.Our
# github.com/allenai/scirepeval.The
# github.com/quantum-dan/raspy
# github.com/tomaszkacprzak/DeepLSS
# github.com/agordon/fastx_
# github.com/ut-osa/ryoan
# github.com/dbacsik/barcode_neutrality
# github.com/Gfeller-Lab/EPIC
# github.com/asahi417/relbert
# github.com/tdurham86/PREDICTD.git
# github.com/stivalaa/ALAAMEE.FundingThis
# github.com/mrzee498/Multimedia-Forensicator
# github.com/clementchadebec/Data
# github.com/THUcqb/KOBE
# github.com/unbabel/openkiwi
# github.com/harlydurbin/mizzou_hairshed_public
# github.com/immunoinformatics/COD-dipp
# github.com/labbces/CoCoView
# github.com/msadat3/SciHTC
# github.com/coffeemuggler/eseis
# github.com/mbonizzato/OptimizeNeurostim
# github.com/flemingtonlab/public
# github.com/gbrammer/msaexp
# github.com/LexTerm/LexTermServer
# github.com/finnlindgren/inlamesh3d
# github.com/keiserlab/e3fp
# github.com/qtabs/fmPitch
# github.com/SamuelBrand1/KenyaCoV
# github.com/yoon28/unpaired
# github.com/ariba-k/fair-loan-predictor
# github.com/CederGroupHub/s4for
# github.com/logangilmour/FoveatedPyramid
# github.com/shahzarrizvi/reweighting-schemes
# github.com/liyangnuaa/Extracting-stochastic-dynam
# github.com/odashi/nmtkit
# github.com/gsartoretti/distributedRL
# github.com/libcnn/libcnn
# github.com/MolecularCellBiologyImmunology/Sialylation_CAF.Any
# github.com/RatAcad/BpodAcademy
# github.com/peritob/Myrtle-rust-genome-assembly
# github.com/hilloc-submission/hilloc
# github.com/rvkrypto/rvkrypto-fips
# github.com/JuliaGPU/CUDAdrv.jl
# github.com/graham1034/Smith2012_insulin_signalling
# github.com/pdebuyl/vmf90
# github.com/DanChitwood/grapevine_morphospace
# github.com/jzchenriver/IRST640
# github.com/PriyeshV/HOPF
# github.com/giuspugl/fgcluster
# github.com/fisicateoricaUDP/HiggsSM
# github.com/alisw/AliPhysics
# github.com/avmoldovan/CNN-TE.We
# github.com/JohnEPool/SIBSAM1
# github.com/HennyJie/BrainGB
# github.com/mullervasconcelos/CDC22.git
# github.com/772435284/QF-portfolio-investment-system
# github.com/philippboehmsturm/ANTX
# github.com/BOBrown/CCDA_LGFA
# github.com/rotroff-lab/salivary-miRNA-HCC
# github.com/ckoven/fates
# github.com/EnMasseProject/amqp-ka
# github.com/AshOlogn/Paragraph-level-Simplification-of-Medical-Texts
# github.com/clason/bouligandlandweber
# github.com/Huang-lab/oppti.Competing
# github.com/danielwood1992/Silene_RNASeq
# github.com/SystemsApproach/private5g
# github.com/elo073/Lung5loc_
# github.com/sinovation/ZEN2
# github.com/grunwaldlab/poppr.Algorithms
# github.com/sedg/ukgds
# github.com/bebraw/273706
# github.com/icon-lab/SynDiff
# github.com/oghenejokpeme/PDECIF
# github.com/polyusmart/Poll-Question-Generation
# github.com/aliborji/objectAnnotation
# github.com/m3project/mantismasking-thresholds
# github.com/DmitryChitalov/OpenFOAM_decompose_GUI
# github.com/dhalperi/linux-80211n-csitool
# github.com/gbradburd/conStruct
# github.com/icarofua/siamese-two-stream
# github.com/Joscolgan/bter_population_genomics
# github.com/steinng/rmarinus
# github.com/alexpancheva/ldapaper
# github.com/wsdream/wsdream-dataset
# github.com/dice-group/THOTH
# github.com/Nesvilab/MSFragger-DIAmanuscript.We
# github.com/imbawenzi/Squill
# github.com/baerlachlan/211130_Q96K97del_A603fs
# github.com/MigueldeLlanza/SynergisticPerception
# github.com/MigueldeLlanza/SynergisticPerception
# github.com/olly-styles/Trajectory-Tensors
# github.com/ColinQiyangLi/LConvNet
# github.com/physh-org/PhySH
# github.com/gbouvignies/ChemEx
# github.com/gbouvignies/ChemEx
# github.com/BTheDragonMaster/mew
# github.com/Ripser/Ripser
# github.com/mwgrassgreen/Alarm
# github.com/ajlee21/ZIKV_diagnostic-
# github.com/uhh-lt/comparative
# github.com/timueh/COVID-19
# github.com/unmannedlab/ROOAD
# github.com/CaseysC/Eudicot_Rcode.causing
# github.com/GavinHaLab/Admixtures_snakemake
# github.com/HYOJINPARK/Reuse
# github.com/thunlp/OpenDelta6.4
# github.com/samiraabnar/attention_flow
# github.com/jakob-r/mlrHyperopt
# github.com/LoganAMorrison/THDMMinimizer
# github.com/epi2me-labs/wf-human-variation
# github.com/epi2me-labs/wf-human-variation
# github.com/divyachoudhary2809/Chaos.Any
# github.com/dnidever/spyderwebb
# github.com/mutin-sa/eea1c396b1e610a2da1e5550d94b0453Proc.ACM
# github.com/giganticode/jemma
# github.com/EtreSerBe/PokeAE
# github.com/EBIBioSamples/biosamples-v4
# github.com/maxmahlke/classy
# github.com/raphaelcohn/bish-bosh
# github.com/aljoshakoecher/machine-skill-model
# github.com/Quetzal-RDF/quetzal
# github.com/bulik/ldsc.Details
# github.com/luca-fiorito-11/sandy
# github.com/Netflix/msl
# github.com/synlp/CiGen
# github.com/ignacio-vegavasquez/supplementary-information
# github.com/Azure/azure-sdk-for-java
# github.com/dynamic11/Banking-ML
# github.com/WeiAkaneDeng/gJLS2
# github.com/pchr8/eval-UA-tion
# github.com/XuyangAbert/CDSC-AL
# github.com/chufangao/GLUE
# github.com/MarcoFusi1980/estabilization-of-the-bacterial-interactomeidentifies-nutrient-restriction-induced-dysbiosis-in-in.git
# github.com/salesforce/AuditNLG
# github.com/flowersteam/sbmltoodejax
# github.com/jpbida/rsim
# github.com/abelgomez/publishsubscribe
# github.com/NickNolan/phage-crispri
# github.com/gabrieloanca/gmxtools.git.To
# github.com/warnikchow/paraKQC
# github.com/MichelaPerrone/SVH_CZ.git
# github.com/UniversalDependencies/UD_Finnish-OOD
# github.com/qi-zh/Seq-Stack-Reaction.Competing
# github.com/Mtac2/Mtac2
# github.com/SemanticComputing/warsa-linkers
# github.com/broadinstitute/wdl
# github.com/yuabrahamliu/CWGCNA
# github.com/Sanyuan-Chen/RecAdam
# github.com/lspecia/quest
# github.com/DmZhukov/CrossTask
# github.com/akamai/re2g.8
# github.com/simongregersen/DepSec
# github.com/Cecca/FRESH
# github.com/google-research-datasets/soft-attributes
# github.com/profxj/mhw
# github.com/UCSD-SASLab/refineCBF
# github.com/TVK-dev/dynamic_graph
# github.com/HaoZeke/eindir
# github.com/jamesjshepherd/uegccd[18,23]
# github.com/g1mishra/Youtube_
# github.com/JFWolters/IdentifyMitoContigs
# github.com/snap-research/CAT
# github.com/mandrecut/vlCryptography
# github.com/scilus/scilpy?fbclid=IwAR2xgpYuNW2Q6CoC06-6FnlLNV
# github.com/lhoou/ms-sm2
# github.com/npjc/readgp1
# github.com/jche253/Glaucoma_Med_Dataset
# github.com/elifesciences-publications/stdpopsim
# github.com/gulinav/_gulinav
# github.com/andresprzh/SEEGFusion.This
# github.com/skmda37/ShearletX
# github.com/RegnerM2015/scBreast_scRNA_scATAC_2024.â€¢
# github.com/utkuozbulak/adaptive-segmentation-mask-attack
# github.com/syrte/ndtest
# github.com/ianan/nustar
# github.com/jlwecoevo/gRodon
# github.com/sz128/slot_filling_and_intent_detection_of_SLU.git
# github.com/THGLab/CSpred
# github.com/PulmonaryMRI/reproducibility
# github.com/sahil280114/codealpaca.:
# github.com/emoran5/range_
# github.com/SSYSteve/Learning-Graph-Representation-with-Task-specific-Topology-and-Multi-dimensional-Edge-Features
# github.com/mbilalzafar/fair-classification
# github.com/micamoret/GlucagonMathModel
# github.com/harvitronix/five-
# github.com/yutao1008/Bi-DNNs
# github.com/stacs-cp/AutoIG
# github.com/cohensimpson/smallnet_ScientificData
# github.com/AutomataTutor/automatatutor-data
# github.com/violetweir/PPYOLO-T
# github.com/NVIDIA/thrust
# github.com/ugo-nama-kun/gym_torcs
# github.com/yanyan5420/J-RESRGAN
# github.com/ganguli-lab/Synaptic-Flow.We
# github.com/evofant/ChimpanzeeMissingLink>.FundingOpen
# github.com/youf3/NVMeoF_fs_performance
# github.com/RiccardoDeMasellis/FLLOAT
# github.com/ulikunitz/xz,respectively.BAM
# github.com/compgenomicslab/CRs
# github.com/aryeelab/guideseq
# github.com/vshahrez/Sun-Bowman-et-al
# github.com/nielsend/genomeassembly
# github.com/ben-aaron188/naive_context_sentiment
# github.com/JasonSWFu/MetricGAN
# github.com/PCWG/PCWG
# github.com/UniTN-KDILab/Business-2018-19
# github.com/BioinformaNicks/PreLeisH_Immuno
# github.com/robinsongeorge/Reduced-Khovanov-Homology
# github.com/acabassi/coca
# github.com/abir-de/SELCON
# github.com/ictnlp/Wait-info
# github.com/t7morgen/misatodataset
# github.com/DFKI-NLP/MoRTy
# github.com/ToshkaDev/Motif
# github.com/vitroid/hyperhomogeneity
# github.com/alfredomg/GeBNLP2019
# github.com/syne-lab/vetiot
# github.com/genomesurveillance/delta-variant-sublineage,which
# github.com/igemsoftware2020/Team_UESTC_Software
# github.com/andreasvc/litvecspace
# github.com/fmatano/KalmanFilteR
# github.com/priyavrat-misra/xrays-and-gradcam.git
# github.com/jorgcalis/JAK1-alleles-pipeline
# github.com/oizumi-lab/PhiToolbox
# github.com/CDMB-lab/IDSSIM.Ethics
# github.com/haesemeyer/imaging_pipeline
# github.com/Nesvilab/PTM-Shepherd
# github.com/GMBA-biodiversity/SDG15.4.1_Calculator.Brief
# github.com/Robcib-GIT/PAUL
# github.com/feizc/Future-Caption.CCS
# github.com/colincwilson/maxentclassphon
# github.com/realtechsupport/c-plus-r.git
# github.com/3DGenomes/tadbit]
# github.com/thunlp/openne
# github.com/OnofriAndreaPG/aomisc
# github.com/OnofriAndreaPG/aomisc
# github.com/OnofriAndreaPG/aomisc
# github.com/PNAI-CSB-NCI-NIH/HORNET
# github.com/SPAAM-community/AncientMetagenomeDirCheck
# github.com/dgzlopes/tcp-latency
# github.com/TheoEst/hippocampus
# github.com/ht50/FLT3_ITD_ext
# github.com/jianhao2016/GPRGNNBaseline
# github.com/geneinmylife/MR-project-Heart-failure
# github.com/LaurentNevou/Light_WaveTransmission1D_dispersion
# github.com/lukalabs/cakechat
# github.com/harvardnlp/sent-summary3
# github.com/luisgls/SSB_selection
# ...
# github.com/LieberInstitute/dRFEtools_manuscript.FundingThis
# github.com/Bartdoekemeijer/zeromqServer-
# github.com/landrylaboratory/Gene_duplication_2019
# github.com/zhaotao1987/SynNet-Pipeline
# github.com/dispersing/SpatialRandomizations
# github.com/h-pawar/gor_ghost_introg.Author
# github.com/3DFetalMRI/fetal-body-organ-segmentation
# github.com/Wenchao-M/HoW-3D
# github.com/owlcollab/owltools.git
# github.com/elisemercury/Duplicate-Image-Finder
# github.com/jenniwestoby/Benchmark_paper_isoforms
# github.com/ToTuanAn/SHREC2022.git
# github.com/Sysinternals/SysmonForLinux
# github.com/schtailmuel/apertium-lld
# github.com/tuvovan/ATTSF
# github.com/alhandwerger/GEE_
# github.com/dhglab/Genome-widechanges-in-lncRNA-alternative-splicing-and-cortical-patterning-in-autism
# github.com/urielsinger/fairwalk
# github.com/ElementAI/N-BEATS.git
# github.com/sstucki/minion
# github.com/PedroRASB/ISNet.Author
# github.com/ricbl/etsaliencymaps
# github.com/ArthurLeroy/MAGMA.The
# github.com/lawrennd/mocap
# github.com/rmvpaeme/cfRRBS_tube_study
# github.com/NDAR/nda_aws_token_generator
# github.com/mhausenblas/reshifter
# github.com/akdess/CaSpER
# github.com/luquelab/hkcage.git
# github.com/Yonsei-MILab/LimQSM.Declaration
# github.com/alfredvc/paac
# github.com/maxburian/SAXS_py3
# github.com/ToepferLab/CalTrack
# github.com/andycasey/sick
# github.com/fbersetche/Finite-elementapproximation-of-fractional-Neumann-problems
# github.com/yangyang-wang/LC_in_square
# github.com/xingyizhou/GTR
# github.com/Diyago/GAN-for-tabular-data,accessed
# github.com/asjacobs92/nia-deployer
# github.com/IndigoMad/Multiplexed-
# github.com/ggiorgione/DynamicPricing
# github.com/ciaranm/parasols
# github.com/TDCOSMO/hierarchy_analysis_2020_
# github.com/mpc-bioinformatics/CalibraCurve
# github.com/pdexheimer/vexd
# github.com/zzz47zzz/CET
# github.com/andresrosso/bioasqdataset
# github.com/stanfordnlp/mac-network
# github.com/nwpu-zxr/VadCLIP
# github.com/TUW-VieVS/VieSchedpp.Author
# github.com/hannorein/rebound.A&A
# github.com/binghong-ml/retro
# github.com/thiippal/gem-tools
# github.com/deminu/Roary
# github.com/IBM/RegionViT
# github.com/realtechsupport/video-informed-image-classification
# github.com/Sashoss/LUAD_PLOS_data.This
# github.com/guidance-ai/guidance
# github.com/facebookresearch/ResNeXt
# github.com/ciads-ut/transfer-learning-ner
# github.com/Adamtaranto/density-Mapr
# github.com/Adamtaranto/density-Mapr
# github.com/PNNL-CompBio/beatamlpilotproteomics
# github.com/bakkerra/smfish_pipeline
# github.com/kungfugo/BellDiagonalQudits.jl.Author
# github.com/goru001/nlp-for-manglish
# github.com/EllenJCoombs/Asymmetry-evolution-cetaceans
# github.com/kibok90/iccv2019-inc
# github.com/saschatimme/LinearCovarianceModels.jl
# github.com/tomazc/iCount
# github.com/tomazc/iCount
# github.com/stopwords-iso/stopwords-isoThe
# github.com/lab42open-team/prego_statistics
# github.com/mahmoodlab/mamba
# github.com/dginev/CorTeX
# github.com/kcios/2021.Software
# github.com/gebel67/WNV_avian_amplicon
# github.com/deepware/deepfake-scanner
# github.com/dorahermes/Paper_Hermes_2019_eLife
# github.com/fpv-iplab/rulstmbranches.Building
# github.com/kumarsaurabh20/bioaqua1
# github.com/djpark1974/raft_hotspots_se
# github.com/mariru/exponential_
# github.com/BMClab/BMC
# github.com/SfinxCZ/Malware-analysis-using-multiple-instancelearning
# github.com/reconhub/outbreaker2
# github.com/brainnetworks/local_scfc
# github.com/shiqiang-lin/genesynthesis
# github.com/shiqiang-lin/genesynthesis
# github.com/CBICA/FeTS
# github.com/yifengtao/genome-transformer.SI
# github.com/oolonek/ISDB
# github.com/MickanAsp/Developmental_heart
# github.com/octavioroncero/madwave3
# github.com/Varyn/WSDM-challenge-2019-spotify
# github.com/croningp/crystal_active_learning
# github.com/gagekmoreno/SARS-CoV-2-in-
# github.com/z337-408/WSNFGVC
# github.com/suzannejin/pcor.bshrink.git
# github.com/OmegaPetrazzini/NAsImpute.DeclarationsEthics
# github.com/adigasu/FDPMNet
# github.com/zakimjz/cSPADE
# github.com/alan23273850/AutoQ
# github.com/sbfnk/fitR
# github.com/ewest11/Bipolar-Serial-SABER-FISH-Analysis
# github.com/upadhye/Cosmic-Enu
# github.com/insapathogenomics/ReporType
# github.com/bentoayr/exact_graph_matchDeclarationsCompeting
# github.com/RoyRabinowitz/CrisPam
# github.com/LabBiosystemUFRN/LeadNPC
# github.com/meadsubmission/MEAD
# github.com/AStcherbinine/omegapy
# github.com/jwuphysics/xSAGA
# github.com/rxn4chemistry/rxnmapper.C
# github.com/iamollas/Altruist
# github.com/Ebony-Watson/scProximitE.Supplementary
# github.com/bytedance/uss
# github.com/delay-tolerant-networking/DTN2
# github.com/JoshuaIszatt/phanatic
# github.com/casanova-lab/iMUBAC
# github.com/DavidHein96/seer-sigmoidoscopy.Conflicts
# github.com/tebbenk/GED
# github.com/GallVp/knkTools
# github.com/mms-fcul/DelPhi4Py
# github.com/mmaaz60/ssl_for_fgvc
# github.com/pism/pism.The
# github.com/alisterburt/napari-subboxer.git
# github.com/alisterburt/napari-subboxer.git
# github.com/alisterburt/napari-subboxer.git
# github.com/NoahApthorpe/iotinspector
# github.com/F00lWise/XNLdyn
# github.com/parovicm/task-arithmetic
# github.com/ollieclarke8787/toric
# github.com/diBernardoGroup/SwarmSimPublic
# github.com/kireevlab/FRASE-bot-Pipeline-Pilot
# github.com/rivas-lab/mrpmm
# github.com/Shoombuatong2527/anticancer-peptides-review
# github.com/Tanveer81/deep
# github.com/KIT-HYD/last-model
# github.com/KIT-HYD/last-model
# github.com/klusta-team/klustaviewa
# github.com/zhengxwen/SNPRelate
# github.com/lwlss/profilyzer_Dubarry2015
# github.com/mariaangelapellegrino/QueDI
# github.com/USSLab/PoltergeistAttack
# github.com/cmodw/emf-profiles_testpetrinet
# github.com/tgasser/OSCAR
# github.com/byandell/FounderCalciumStudy,copy
# github.com/aitechlabcn/neUNet
# github.com/momentoscope/hextof-processor
# github.com/mandadapu-group/active-contact
# github.com/jhardenberg/PLASIM.Data
# github.com/eichstaedtPTB/PyDynamic
# github.com/alexandr-fonari/emc,\"
# github.com/HQ01/BOWMIAN
# github.com/SysBioChalmers/GECKO
# github.com/MILES-PSL/upper_bound_lipschitz_convolutional_layers
# github.com/niconaus/PCode-Dump
# github.com/wei-mao-2019/HisRepItself
# github.com/Jorisvansteenbrugge/GROS_genomes
# github.com/knowitall/openie
# github.com/lasigeBioTM/MRRAD
# github.com/WHaasNY/LegioCluster
# github.com/Amarashdeh/FP-PHP-C-TestPrograms
# github.com/jlp2duke/EnsCat
# github.com/MagneticParticleImaging/OpenMPIData.jl.git
# github.com/goncalofcarnaz/Annotated-Corpusof-Criminal-Related-Portuguese-Documents
# github.com/ETCBC/laf-fabric
# github.com/adamlek/ud-morphological-tagging
# github.com/OmegaProject/Omega
# github.com/scottgs/metadataset_objects,accessed
# github.com/andlab-um/OT-cpm.ORCIDHaoming
# github.com/dhteodoro/upclass
# github.com/FloHugon/DataFormatting
# github.com/iqbal-lab-org/cryptic_tb_callable_
# github.com/blockchain-group/DGO
# github.com/CampagneLaboratory/goby
# github.com/ysmiao/nvdm
# github.com/Sherlock-Lab/Diff-seq
# github.com/RyanXingQL/MFQEv2.0
# github.com/CosmoLike/CosmoCov_Fourier
# github.com/Robaina/prochlorococcus
# github.com/mortonjt/q2-differential
# github.com/Annefeng/PBK-QC-pipeline
# github.com/philiptheother/FeatureDecoupling
# github.com/kazumits/tissueChIL
# github.com/TheAmadeus25/Oscilloscope32
# github.com/microsoft/SpeechT5
# github.com/ShiLevy/SGAN_ME
# github.com/AMPByrne/WGS
# github.com/Clinical-Genomics/reference-
# github.com/CSBiology/FSharp.Stats
# github.com/IldikoPilan/swell-norm
# github.com/Code-master2020/MPRAdecoder
# github.com/stefania11/ScratchCopilot-Evaluation
# github.com/PathwayCommons/sbgnml-
# github.com/theislab/Scanpy
# github.com/OpenGenomics/mc3
# github.com/boutroslab/cld
# github.com/headacheboy/IGSQL
# github.com/dragonflyoss/Dragonfly
# github.com/broadinstitute/crom
# github.com/RF5/simple-sashimi
# github.com/atharva-kelkar/hydrophobicity-features
# github.com/Bahler-Lab/pyphe-slim
# github.com/ging/sgame_platform
# github.com/arifein/atm-Hg-3boxmodel
# github.com/lstothert/two_pcf0.02
# github.com/hwwang55/MKR
# github.com/fuzzm/fuzzm-project
# github.com/astrobrent/itera
# github.com/HouZi64/AMPNN.This
# github.com/ravellab/M_and_M\"
# github.com/Unbabel/COMET#lan
# github.com/autowarefoundation/autoware
# github.com/rachaelhach/NATCOMM_Cherenkov_HU
# github.com/bartoszpankratz/ABCDe_Experiments
# github.com/lancelot0821/Special_issue_rice_authenticity.COMPETING
# github.com/yamizi/Adversarial-Embedding
# github.com/YeoLab/repetitive-elementmapping
# github.com/cair/PyCoalescedTsetlinMachineCUDA
# github.com/rajinder4489/FuSe
# github.com/uschiLaa/paper-
# github.com/UCLA-PHP/school.epi.abm.Conflict
# github.com/zouw2/oc_metrics
# github.com/ganguli-lab/Synaptic-Flow
# github.com/Elysheba/Orphanet
# github.com/jbelyeu/unfazed
# github.com/Valledor/pRocessomics
# github.com/pycroscopy/AICrystallographer
# github.com/gdubach/Zagier_project
# github.com/peterlau0626/semeval2023-task4-HumanValue
# github.com/HLTCHKUST/sentiment-lookahead
# github.com/pierrethx/MVT-binning
# github.com/dorlivne/PoPS
# github.com/paracrawl/Malign
# github.com/evanslaboratory/Extensions
# github.com/davideboscaini/PatchMixer
# github.com/satijalab/seurat-data.In
# github.com/Hugo101/PLATINUM
# github.com/Duke-QCD/trento
# github.com/benjamincjackson/dsim_variant_pipeline_ref_v2.02.git.Multispecies
# github.com/nlp-uoregon/behancecc
# github.com/NMSL-DGIST/PyMUS
# github.com/Zhongbo-Hu/Prediction-Evolutionary-Algorithm-HOMEPAGE.INDEX
# github.com/mjbasso/asymptotic_formulae_examples
# github.com/yicjia/CausalDeepCENT
# github.com/leggedrobotics/tree_detection
# github.com/soo89/CSD-SSD
# github.com/UestcJay/GraphFit
# github.com/greenlabjhmi/2021_TrmD
# github.com/swshon/dialectID
# github.com/yangliuqing1992/Integrative_clustering
# github.com/kpu/kenlm
# github.com/newcat/baklavajs
# github.com/tomwenseleers/newcovid_
# github.com/adamkoziol/minion_amplicon.MiSeq
# github.com/mil-tokyo/vqg-unknown
# github.com/compdyn/learning-oras
# github.com/IBM/IBM
# github.com/ESA-PhiLab/WorldCrops
# github.com/DanChitwood/PassifloraLeaves
# github.com/vastc/.Steps
# github.com/NIVANorge/seasonal_
# github.com/herjy/scarlet
# github.com/dyvasey/dz-caucasus
# github.com/AilabUdineGit/ade-detection-survey
# github.com/zihangdai/mos
# github.com/ZhiLiu724/librarydisparities.Related
# github.com/IITH-Compilers/drb_fortran
# github.com/HuiStudent/Cross-type_SDN
# github.com/sustc-xylab/metaRUpore
# github.com/berebolledo/mtDNA22q
# github.com/gkumar09/iSeqQC
# github.com/TRASAL/AMBER
# github.com/tlx/tlx
# github.com/vishnubob/python-midi
# github.com/BioAnalyticResource/Arapor-t_ePlant
# github.com/frbkrm/HomophilicNtwMinorities.git
# github.com/Junshuai1043/BinVPR
# github.com/Csogeza/EmiPhotoZ
# github.com/liangyy/haplotype-po
# github.com/BenjaminPeter/schornig_ineuron
# github.com/chhylp123/Hifiasm
# github.com/andraszsom/HUNTER
# github.com/liuhuanyong/CCKS2018Summary
# github.com/UoS-SCCS/VirtualWebAuthn
# github.com/lijotgeorge/upper-limit-calculator
# github.com/komi786/SemanticAnnotator
# github.com/afariha/SubSumE
# github.com/VarunGumma/indic_nlp_
# github.com/poldracklab/fmriprep
# github.com/rachaelmburke/tbcovidblantyre
# github.com/ranczlab/Galloni.etal.2022
# github.com/leondgarse/keras
# github.com/dingswin/calibrator_models_
# github.com/mtrw/tim_bioinfo_
# github.com/saalfeldlab/template-building
# github.com/yingstat/intePareto
# github.com/cmzuo11/scMVAE
# github.com/Kaplan-Lab-Pitt/TLs_Screening.git
# github.com/RAbolafiaRosenzweig/NoahMP_SWE_DirectInsertion_Updates.Constraining
# github.com/yuzhesong/stacking_funcs_tutorial
# github.com/pirkkao/OpenEPS
# github.com/MengyangGu/RobustGaSP-in-Matlab
# github.com/jamesjshepherd/uegccd
# github.com/anwala/general-language-behavior.FundingThis
# github.com/HBSG1996/phm-ieee-2012-data-
# github.com/danielgribel/hg-means
# github.com/nyumll/crowdsourcing-protocol-comparison
# github.com/agchung/Actualmed-COVID-chestxray-dataset
# github.com/Kohulan/DECIMER-Image-Segmentation
# github.com/cma2015/PEA-
# github.com/astromosk/imred
# github.com/lab-cosmo/skmatter-ore.This
# github.com/jarredclloyd/PowerShell_LADR_
# github.com/JaywongWang/CBP
# github.com/mhardcastle/radioflux
# github.com/transmart/SmartR
# github.com/BCM-DLDCC/nursa
# github.com/peterberr/US_county_HSM
# github.com/delphes/delphes
# github.com/DKFZ-ODCF/SophiaWorkflow
# github.com/JasonForJoy/MPC-BERT
# github.com/jrowberg/i2cdevlib
# github.com/basiralab/AGSR-Net
# github.com/moucheng2017/Learning_Morphological_Perturbation_SSL
# github.com/bgroenks96/AutoMoL
# github.com/SforAiDl/KD
# github.com/hydrogo/LHMP,Ayzel
# github.com/SanneLamers/FlySocial
# github.com/DolevAdas/Jiffy
# github.com/b-tierney/pds08
# github.com/travis-ci/travis-build
# github.com/wangsc1912/ESGNN
# github.com/nanopore-wgs-consortium/chm13
# github.com/ZhouKanglei/HGCN_AQA
# github.com/MIC-DKFZ/TractSeg
# github.com/MIC-DKFZ/TractSeg
# github.com/thlytras/bayEStim
# github.com/zhoupc/OASIS_matlab
# github.com/gugarosa/opfython
# github.com/RedaRawi/bNAb-ReP
# github.com/dphansti/Sushi
# github.com/ohdsi/cohortmethod
# github.com/tauanajc/phylo_scripts.223The
# github.com/petitioner/ML.MulticlassLRtraining
# github.com/nasedkinav/rst_corpus_rus
# github.com/aguedaprojectugr/Muscular_-strength_Mental_health.git
# github.com/richardtml/DIViTA
# github.com/Dogrinev/Seroplacer_Manuscript
# github.com/nickbruun/hayai
# github.com/sqiangcao99/VCM
# github.com/kaiwenw/DPDDT
# github.com/brutalni-vux/IsogeniesQuadratic
# github.com/zhuqingpeng/MIPI2022-RGB-ToF-depth-completion
# github.com/mplotnyko/exopie
# github.com/berenslab/spikefinder_analysis
# github.com/globus-labs/MERF-FSP
# github.com/sgboakes/pysatellite
# github.com/Paleogenomics/Chrom-Compare
# github.com/agermanidis/pigeon
# github.com/ch-shin/ENERTALK-dataset
# github.com/chassall/averagetaskvalue
# github.com/ichcha-m/cophescan.A
# github.com/yaseen21khan/Classification-of-Heart-Sound-Signal-Using-Multiple-Features-
# github.com/FlowSs/How-to-Certify-Machine-Learning-BasedSafetycritical-Systems-A-Systematic-Literature-Review
# github.com/Jbrich95/sdfExtreme
# github.com/satra/VocalTractModels
# github.com/hallamlab/mp_tutorial
# github.com/mathialm/Adversarial-
# github.com/GeoStat-Examples/gstools-connectivity-and-transport
# github.com/CCS-Lab/hBayesDM
# github.com/CCS-Lab/hBayesDM
# github.com/xcccc402/Touchscreen-version-of-PR-task-data-analyasis.git
# github.com/jmerrtt2/ChemostatImageProcessing
# github.com/colabobio/borrelia-diagnosis-prediction-models.AcknowledgementsWe
# github.com/ged/ruby-wordnet
# github.com/titu1994/tfdiffeq
# github.com/CausalML/BLearner
# github.com/Chandan-IITI/One-Class-Kernel-ELM
# github.com/ChihYuLee/Thin-film-optics-
# github.com/ckassaad/Case_Studies_of_Causal_Discovery_from_IT_
# github.com/nodag/psa
# github.com/blah957/blah957lstm-sagDTA.FUNDINGThis
# github.com/clovaai/CutMix-PyTorch'
# github.com/HaigangLiu/spatial-temporal-py
# github.com/joey1993/bert-defender
# github.com/forge/roaster
# github.com/joshuachang2311/chorder
# github.com/GFNOrg/EB_GFN
# github.com/celinehocquette/magicpopper.git
# github.com/SiwoResearch/generative_AI_nucleosides
# github.com/salimkhazem/Control-Motors-with-
# github.com/githublyy0325/COVIDHeterogeneity
# github.com/NKI-AI/mra_segmentation
# github.com/twbs/bootstrap
# github.com/saleiro/Financial-Sentiment-Analysis
# github.com/JoannaAch/MS_2019
# github.com/MicKr4ne/iwire-av
# github.com/benedekrozemberczki/pytorch
# github.com/hutchisonlab/QupKake
# github.com/ZitongYu/Flex-Modal-FAS
# github.com/benhid/nora.reasoning
# github.com/LSSTDESC/tomo
# github.com/kuffmode/ANNLesionAnalysis
# github.com/JohannesOehm/FhirExtinguisher
# github.com/bkfly/test.git
# github.com/greymonroe/brachypodium_fvt
# github.com/cyhsuTN/scLR
# github.com/reichlab/ncov
# github.com/FairRootGroup/FairRoot
# github.com/priyamoorjani/baboon
# github.com/UFRGS-CAROL/carol-fi
# github.com/wjnGXNU/Fusion-modelAUTHOR
# github.com/josedv82/airball
# github.com/lukewtait/microstate_toolbox.Furthermore
# github.com/hsinyuan-huang/predicting-quantum-properties
# github.com/Haoang97/MEDI
# github.com/ScottLabUCB/FEM
# github.com/wwwwwyyyyyxxxxx/SA2GVANDigital
# github.com/NVlabs/stylegan2.Funding:
# github.com/QcmPlab/DriverDatabase
# github.com/Rania2016/20-FACEBOOK-CONVERSATIONS
# github.com/QingyuLiu/Exposing-the-Deception
# github.com/olliestephenson/dpm-rnn-public
# github.com/Britefury/domain_adapt_self_ensemble
# github.com/RWTH-i5-IDSG/ixsi
# github.com/unm-hscl/ajthor-ortiz-L4DC2021
# github.com/dmuraka/SimplePoissonApprox_MCsim
# github.com/robotics-upo/marsupial_optimizer
# github.com/theoryinpractice/mandoline
# github.com/euffelmann/bpc.Individual-level
# github.com/PetarV-/GAT
# github.com/Sameerer/Joint-SNF
# github.com/ByronJi/DRGCL
# FINISHED SOURCE PORTION
