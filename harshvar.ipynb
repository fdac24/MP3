# %% [markdown]
# # Code

# %%
import json, re, requests, gzip
from tqdm import tqdm
from urlextract import URLExtract
# import bibtexparser

# %%
# Initialize URL extractor and DOI pattern
url_extractor = URLExtract()
doi_pattern = r'\b(10\.\d{4,9}\/[-._;()/:A-Z0-9]+)\b'

def get_urls(content):
    """Extract URLs from text."""
    return url_extractor.find_urls(content)

def get_dois(content):
    """Extract DOIs based on regex."""
    return re.findall(doi_pattern, content)

# def get_bibtex_entries(content):
#     """Extract Bibtex entries."""
#     try:
#         bib_data = bibtexparser.loads(content)
#         return bib_data.entries
#     except:
#         return []

def fetch_readme(url, TIMEOUT = 10):
    """Fetch README content with timeout (default 10 secs) and fallback for GitHub."""
    try:
        response = requests.get(url, timeout=TIMEOUT)
        if response.status_code != 200 and 'github.com' in url:
            # Try alternative URL for GitHub main branch
            url = url.replace('/master/', '/main/')
            response = requests.get(url, timeout=TIMEOUT)
        return response.text if response.status_code == 200 else None
    except requests.RequestException:
        print(f"Skipping {url} due to timeout or connection error.")
        return None

def process_entry(id, source_type, base_url, readme_path):
    """Retrieve README, extract details, and organize data."""
    
    if source_type == "source":
        # Split the line to extract just the URL part
        _, line = id.split(';')
        # Construct the URL specifically for GitHub repos
        full_url = f"{base_url}{line[11:]}{readme_path}"
    else:
        # Use the original method for model and data
        full_url = f"{base_url}{id}{readme_path}"

    
    content = fetch_readme(full_url)
    if content:
        return {
            "id": id,
            "type": source_type,
            "url": full_url,
            "content": content.replace("\n", " "),
            "links": get_urls(content),
            "dois": get_dois(content)#,
            # "bibs": get_bibtex_entries(content)
        }
    return None

# %%
output_file = gzip.open("output/harshvar.json.gz", 'wt', encoding="utf-8")
source_files = {"model": "input/harshvar_model", "data": "input/harshvar_data", "source": "input/harshvar_source"}
base_urls = {
    "model": "https://huggingface.co/",
    "data": "https://huggingface.co/datasets/",
    "source": "https://raw.githubusercontent.com/"
}
readme_paths = {
    "model": "/raw/main/README.md",
    "data": "/raw/main/README.md",
    "source": "/master/README.md"
}

for source_type, input_file in source_files.items():
    with open(input_file, 'r') as f:
        for line in f:
            line = line.strip()
            entry = process_entry(line, source_type, base_urls[source_type], readme_paths[source_type])
            if entry:
                json.dump(entry, output_file)
                output_file.write("\n")
                print(f"Processed {entry['id']} from {source_type}.")
output_file.close()
# Out:
# Processed bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF from model.
# Processed mradermacher/Boundary-4x7b-MoE-i1-GGUF from model.
# Processed Weyaxi/Einstein-v4-7B from model.
# Processed EarthnDusk/May2023-Models from model.
# Processed Vedx04/MetaMath-Mistral-7B-hendrycks from model.
# Processed sudhanshu746/deepseek-7b-instruct-matho-finetune from model.
# Processed leonn71/gte-Qwen2-1.5B-instruct-Q6_K-GGUF from model.
# Processed AI4PD/ZymCTRL from model.
# Processed KappaNeuro/director-darren-aronofsky-style from model.
# Processed matheusgeda/testando from model.
# Processed Theta-Lev/deepseek-math-7b-rl-Q8_0-GGUF from model.
# Processed Zainiii/flanT5-738-lora-math from model.
# Processed reyvan/bert_large_maths from model.
# Processed jonas-luehrs/bert-base-cased-MLM-chemistry from model.
# Processed torchgeo/resnet18_sentinel2_all_moco from model.
# Processed Shaleen123/gemma2-9b-maths from model.
# Processed maldv/electric-sheep-7b-alpha from model.
# Processed TheBloke/OpenAssistant-Llama2-13B-Orca-8K-3319-GGUF from model.
# Processed multimolecule/splicebert-human.510nt from model.
# Processed TGrote11/Math_Classification from model.
# Processed tum-nlp/IDMGSP-Galactica-TRAIN_GPT3 from model.
# Processed scvi-tools/tabula-sapiens-spleen-scanvi from model.
# Processed aflah/Meta-Llama-3-8B-instruct__Climate-Science-Steps-60__Merge-to-4-bit from model.
# Processed LoneStriker/nontoxic-bagel-34b-v0.2-5.0bpw-h6-exl2 from model.
# Processed LoneStriker/SauerkrautLM-Mixtral-8x7B-Instruct-3.5bpw-h6-exl2 from model.
# Processed dotan1111/BioTokenizer-BFD-BPE-200 from model.
# Processed QuantFactory/internlm2-math-plus-1_8b-GGUF from model.
# Processed cloudqi/cqi_question_solver_translator_v0 from model.
# Processed arcdev/e5-mistral-7b-instruct from model.
# Processed 1aurent/densenet161.tiatoolbox-kather100k from model.
# Processed minhnguyen/Advanced_B-cell_Epitopes_Prediction from model.
# Processed AnandMK/ULFEarthquake from model.
# Processed paulml/ECE-ILAB-Q1 from model.
# Processed VickiPol/binary_models from model.
# Processed MaziyarPanahi/blossom-v3_1-mistral-7b-Mistral-7B-Instruct-v0.1-GGUF from model.
# Processed techysanoj/roberta-fine-tuned-squadv2 from model.
# Processed hw2942/bert-base-chinese-climate-related-prediction-v2 from model.
# Processed internlm/internlm2-math-plus-mixtral8x22b from model.
# Processed BVRA/tf_efficientnet_b0.in1k_ft_df20m_384 from model.
# Processed mevol/BiomedNLP-PubMedBERT-ProteinStructure-NER-v2.1 from model.
# Processed automerger/T3qM7-7B from model.
# Processed CMU-AIR2/math-deepseek-LORA-ArithHard-FTMWP-LORA from model.
# Processed yuiseki/tinyllama-coder-math-ja-wikipedia-v0.1 from model.
# Processed HuangLab/CELL-E_2_OpenCell_640 from model.
# Processed mlx-community/dolphin-2.9.1-yi-1.5-34b-8bit from model.
# Processed lamm-mit/BioinspiredLLM from model.
# Processed fine-tuned/BAAI_bge-large-en-v1_5-1562024-to89-webapp from model.
# Processed CMU-AIR2/math-phi-1-5-FULL-Arithmetic-lr-1.5e-6 from model.
# Processed multimolecule/rnamsm from model.
# Processed researchaiic/LandAUMath2 from model.
# Processed PDBEurope/BiomedNLP-PubMedBERT-ProteinStructure-NER-v1.4 from model.
# Processed BVRA/mobilenetv2_100.in1k_ft_df20_299 from model.
# Processed Kukedlc/NeuralMathsRolePlay-7b from model.
# Processed ostapeno/ng_1B_lib_embeddings_replace_distinct10 from model.
# Processed qilowoq/AbLang_heavy from model.
# Processed ForRiver/metamath-mistral-lora-7b from model.
# Processed rmuema/kaggle-x-elo-finetune from model.
# Processed mathrrab/q-taxi from model.
# Processed hw2942/chinese-macbert-base-climate-related-prediction-v3 from model.
# Processed imageomics/butterfly_detection_yolo from model.
# Processed MaziyarPanahi/jackalope-7b-Mistral-7B-Instruct-v0.1 from model.
# Processed zhangtaolab/plant-dnagemma-H3K27me3 from model.
# Processed SrimathiE21ALR044/AI_chatbot from model.
# Processed mradermacher/dolphin-2.9.1-llama-3-70b-GGUF from model.
# Processed marcelomathias/mistral_7b_lora_equus from model.
# Processed pszemraj/bigbird-pegasus-large-K-booksum from model.
# Processed stabilityai/stablelm-zephyr-3b from model.
# Processed premsuresh/bart-finetuned-mathqa-mohith from model.
# Processed severcorp/flant5 from model.
# Processed lamm-mit/Bioinspired-Llama-3-1-70B-128k-alpha from model.
# Processed Climate-TwitterBERT/Climate-TwitterBERT-xmas from model.
# Processed mlx-community/granite-34b-code-instruct-8bit from model.
# Processed TheBloke/tora-13B-v1.0-GPTQ from model.
# Processed vectoriseai/gte-base from model.
# Processed CMU-AIR2/deepseek-math-base-LORA-ArithSteps-8k from model.
# Processed SivilTaram/poet-math-digit from model.
# Processed open-llm-leaderboard-old/details_jambroz__sixtyoneeighty-7b from data.
# Processed open-llm-leaderboard-old/details_jeiku__Garbage_9B from data.
# Processed open-llm-leaderboard-old/details_OpenBuddy__openbuddy-mixtral-7bx8-v16.3-32k from data.
# Processed open-llm-leaderboard-old/details_l3utterfly__mistral-7b-v0.1-layla-v4 from data.
# Processed open-llm-leaderboard-old/details_cgato__TheSpice-7b-FT-ExperimentalOrca from data.
# Processed open-llm-leaderboard-old/details_Kquant03__CognitiveFusion-4x7B-bf16-MoE from data.
# Processed OALL/details_meta-llama__Llama-2-13b-hf from data.
# Processed open-llm-leaderboard-old/details_Qwen__Qwen1.5-7B-Chat from data.
# Processed open-llm-leaderboard-old/details_Doctor-Shotgun__CalliopeDS-v2-L2-13B from data.
# Processed dharun2049/dermaflow-v1 from data.
# Processed joey234/mmlu-college_biology from data.
# Processed open-llm-leaderboard-old/details_arlineka__KittyNyanster-v1 from data.
# Processed OALL/details_Orenguteng__Llama-3.1-8B-Lexi-Uncensored-V2 from data.
# Processed open-llm-leaderboard-old/details_Lvxy1117__amber_fine_tune_sg_part1 from data.
# Processed open-llm-leaderboard-old/details_SC99__Mistral-7B-privatemix-ia3 from data.
# Processed open-llm-leaderboard-old/details_uukuguy__speechless-coding-7b-16k-tora from data.
# Processed open-llm-leaderboard-old/details_viethq188__Rabbit-7B-v2-DPO-Chat from data.
# Processed efederici/biologia-mc from data.
# Processed open-llm-leaderboard-old/details_jikaixuan__test_model from data.
# Processed jiawennnn/STimage-1K4M from data.
# Processed philschmid/slimorca-dedup-chatml-100k from data.
# Processed shuangyu226/myDataset1 from data.
# Processed open-llm-leaderboard-old/details_cyberagent__calm2-7b-chat-dpo-experimental from data.
# Processed danjacobellis/imagenet-1k-walloc-originalsize from data.
# Processed OALL/details_nvidia__Llama3-ChatQA-1.5-8B from data.
# Processed open-llm-leaderboard-old/details_CallComply__SOLAR-10.7B-Instruct-v1.0-128k from data.
# Processed open-llm-leaderboard-old/details_Locutusque__Hercules-3.0-Mistral-7B from data.
# Processed open-llm-leaderboard-old/details_automerger__ShadowYam-7B from data.
# Processed openclimatefix/gfs-reforecast from data.
# Processed open-llm-leaderboard-old/details_alexredna__TinyLlama-1.1B-Chat-v1.0-reasoning-v2-dpo from data.
# Processed open-llm-leaderboard-old/details_wang7776__vicuna-7b-v1.3-attention-sparsity-20 from data.
# Processed open-llm-leaderboard-old/details_liminerity__Omningotex-7b-slerp from data.
# Processed open-llm-leaderboard-old/details_wang7776__vicuna-7b-v1.3-sparsity-10 from data.
# Processed open-llm-leaderboard-old/details_hedronstone__OpenHermes-7B-Symbolic from data.
# Processed open-llm-leaderboard-old/details_EleutherAI__pythia-6.9b-deduped from data.
# Processed haijian06/Advanced-Math from data.
# Processed HydraLM/biology_dataset_list_dict from data.
# Processed open-llm-leaderboard-old/details_AA051610__Q from data.
# Processed open-llm-leaderboard-old/details_Azure99__blossom-v4-qwen1_5-14b from data.
# Processed open-llm-leaderboard-old/details_CHIH-HUNG__llama-2-13b-FINETUNE3_3.3w-r4-q_k_v_o_gate_up_down from data.
# Processed open-llm-leaderboard-old/details_TurkuNLP__gpt3-finnish-small from data.
# Processed open-llm-leaderboard-old/details_PocketDoc__Dans-CreepingSenseOfDoom from data.
# Processed Azure99/blossom-math-v2 from data.
# Processed joey234/mmlu-high_school_physics-rule-neg-prepend from data.
# Processed open-llm-leaderboard-old/details_chaoyi-wu__MedLLaMA_13B from data.
# Processed ccdv/arxiv-classification from data.
# Processed open-llm-leaderboard-old/details_NovoCode__Metabird-7b-DPO from data.
# Processed Mxode/Baike-Astronomy-ZH from data.
# Processed PDBEurope/protein_chain_conformational_states from data.
# Processed samhog/psychology-RLHF from data.
# Processed AcaSp/DomainSpeech from data.
# Processed open-llm-leaderboard-old/details_charlesdedampierre__TopicNeuralHermes-2.5-Mistral-7B from data.
# Processed open-llm-leaderboard-old/details_ChaoticNeutrals__RP_Vision_7B from data.
# Processed dafun/open-web-math-clean from data.
# Processed open-llm-leaderboard-old/details_Azazelle__Sina-Thor-7b-Merge from data.
# Processed open-llm-leaderboard-old/details_hoskinson-center__proofGPT-v0.1 from data.
# Processed open-llm-leaderboard-old/details_bardsai__jaskier-7b-dpo-v3.3 from data.
# Processed open-llm-leaderboard-old/details_Kukedlc__neuronal-7b-Mlab from data.
# Processed open-llm-leaderboard-old/details_TheBloke__airoboros-33B-gpt4-1-4-SuperHOT-8K-fp16 from data.
# Processed open-llm-leaderboard-old/details_Evaloric__Evaloric-1.1B from data.
# Processed open-llm-leaderboard-old/details_Azazelle__Moko-DARE from data.
# Processed open-llm-leaderboard-old/details_Kquant03__NeuralTrix-7B-dpo-relaser from data.
# Processed open-llm-leaderboard-old/details_chargoddard__average-dolphin-8x7B from data.
# Processed open-llm-leaderboard-old/details_bhenrym14__airophin-13b-pntk-16k-fp16 from data.
# Processed open-llm-leaderboard-old/details_BarraHome__Mistroll-7B-v0.2-16bit from data.
# Processed open-llm-leaderboard-old/details_dillfrescott__amadeus-v0.1 from data.
# Processed open-llm-leaderboard-old/details_jsfs11__HighdensityRPMerge-7B from data.
# Processed ai2lumos/lumos_unified_ground_iterative from data.
# Processed zpn/pcba_686978 from data.
# Processed open-llm-leaderboard-old/details_kwchoi__DPO_mistral_v01_7b_ultra_0130_1k from data.
# Processed Tural/MetaMathQA from data.
# Processed mauyu/earth_chan from data.
# Processed open-llm-leaderboard-old/details_Danielbrdz__Barcenas-3b from data.
# Processed open-llm-leaderboard-old/details_JCX-kcuf__Mistral-7B-v0.1-gpt-4-20k from data.
# Processed open-llm-leaderboard-old/details_klosax__open_llama_13b_600bt_preview from data.
# Processed open-llm-leaderboard-old/details_Sharathhebbar24__convo_bot_gpt_v1 from data.
# Processed Zaid/mmlu-random-1 from data.
# Processed open-llm-leaderboard-old/details_leveldevai__MarcDareBeagle-7B from data.
# Processed open-llm-leaderboard-old/details_jjaaaww__posi_13b from data.
# Processed open-llm-leaderboard-old/details_OEvortex__HelpingAI-Lite-2x1B from data.
# Processed open-llm-leaderboard-old/details_xformAI__facebook-opt-125m-qcqa-ub-6-best-for-q-loss from data.
# Processed open-llm-leaderboard-old/details_mayacinka__yam-sam-7B from data.
# Processed open-llm-leaderboard-old/details_UCLA-AGI__test_final from data.
# Processed open-llm-leaderboard-old/details_senseable__moe-x33 from data.
# Processed open-llm-leaderboard-old/details_saarvajanik__facebook-opt-6.7b-gqa-ub-16-best-for-KV-cache from data.
# Processed sled-umich/TRIP from data.
# Processed open-llm-leaderboard-old/details_freecs__ThetaWave-7B-v1 from data.
# Processed julien-c/kaggle-hugomathien-soccer from data.
# Processed autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-1bbcaf-1917164991 from data.
# Processed OALL/details_inceptionai__jais-family-30b-8k-chat from data.
# Processed open-llm-leaderboard-old/details_L-R__LLmRA-3B-v0.1 from data.
# Processed YurtsAI/named_entity_recognition from data.
# Processed hon9kon9ize/yue-math-preference from data.
# Processed open-llm-leaderboard-old/details_jefferylovely__SuperThetaMaven from data.
# Processed open-llm-leaderboard-old/details_quantumaikr__QuantumLM-70B-hf from data.
# Processed open-llm-leaderboard-old/details_SF-Foundation__Ein-72B-v0.13 from data.
# Processed Xuehai/MMWorld from data.
# Processed open-llm-leaderboard-old/details_jisukim8873__falcon-7B-case-8 from data.
# Processed open-llm-leaderboard-old/details_wang7776__Llama-2-7b-chat-hf-30-sparsity from data.
# Processed open-llm-leaderboard-old/details_caisarl76__mistral-guanaco1k-ep2 from data.
# Processed 1;github.com/bjl2n/tjhd_prevalence_of_obesity from source.
# Processed 1;github.com/boc5244/CrazyFly from source.
# Processed 1;github.com/Dio990521/SAEDS from source.
# Processed 1;github.com/engjefersonsantiago/P4HLS from source.
# Processed 1;github.com/Natlem/M-HTCN from source.
# Processed 1;github.com/jules-leguy/BBOMol from source.
# Processed 1;github.com/rezazad68/fewshot-segmentation from source.
# Processed 1;github.com/awesome-davian/pixelsne from source.
# Processed 1;github.com/umanlp/DS-TOD from source.
# Processed 2;github.com/ale-mendez/ESPNN from source.
# Processed 1;github.com/jose-ameijeiras/Car-crashes-data from source.
# Processed 1;github.com/gmantele/vollt from source.
# Processed 1;github.com/zoghbi-a/aztools from source.
# Processed 1;github.com/LirongWu/FF-G2M from source.
# Processed 2;github.com/Hsankesara/DeepResearch from source.
# Processed 1;github.com/kvegesan-stjude/SHIVERS2 from source.
# Processed 1;github.com/kamenoseiji/ALMA-2016.1.00375.S from source.
# Processed 2;github.com/mkleehammer/pyodbc from source.
# Processed 1;github.com/Spatial-R/EvoEnvFlu from source.
# Processed 1;github.com/manellopez13/dl4rf_meta_analysis from source.
# Processed 1;github.com/PoisonAlien/Maftools from source.
# Processed 1;github.com/cduck/orchestrated-trios from source.
# Processed 1;github.com/WuLoli/GAEseq from source.
# Processed 10;github.com/linnabrown/run_dbcan from source.
# Processed 2;github.com/HumanCellAtlas/metadata-schema from source.
# Processed 12;github.com/yoheinakajima/babyagi from source.
# Processed 1;github.com/Dallinger/Dallinger from source.
# Processed 1;github.com/michaelklachko/noisynet from source.
# Processed 1;github.com/kolecki4/PyKMOD from source.
# Processed 1;github.com/MicheleUIT/Explaining_SGNN from source.
# Processed 2;github.com/kipoi/manuscript from source.
# Processed 3;github.com/GiocomoLab/ln-model-of-mec-neurons from source.
# Processed 1;github.com/HDI-Project/SDV from source.
# Processed 1;github.com/digama0/mm0 from source.
# Processed 6;github.com/ontop/ontop from source.
# Processed 5;github.com/ye-kyaw-thu/sylbreak from source.
# Processed 1;github.com/zijguo/Searching-Sampling-Replication from source.
# Processed 1;github.com/FaultyIsogenies/faulty-isogeny-code from source.
# Processed 2;github.com/Openning07/GPA from source.
# Processed 1;github.com/kennymckormick/ARAS-Dataset from source.
# Processed 10;github.com/FDA/CiPA from source.
# Processed 1;github.com/li-xirong/mmc-amd from source.
# Processed 1;github.com/PeteHeine/pedestrian_detector_ros from source.
# Processed 1;github.com/anvaly/SpatialPortal from source.
# Processed 1;github.com/rii-mango/papaya from source.
# Processed 1;github.com/js2251/WaveglowHI from source.
# Processed 1;github.com/UiO-CS/tf-wavelets from source.
# Processed 1;github.com/oliverphilcox/BOSS-Without-Windows from source.
# Processed 1;github.com/Nanguage/Regeneration from source.
# Processed 2;github.com/seqcode/IDEAS from source.
# Processed 5;github.com/MIRTK/DrawEM from source.
# Processed 1;github.com/CBMIWU/demo-dashboard from source.
# Processed 1;github.com/bips-hb/srsim from source.
# Processed 1;github.com/2vin/yolo_annotation_tool from source.
# Processed 1;github.com/rahulyesantharao/batch-dynamic-kdtree from source.
# Processed 1;github.com/FredHutch/sra-pipeline from source.
# Processed 1;github.com/GrazingScientist/TaggedTextTokenizer from source.
# Processed 1;github.com/cmshobe/pub_shobe_etal_GMD from source.
# Processed 7;github.com/kwagstyl/surface_tools from source.
# Processed 1;github.com/afeinstein20/young-stellar-flares from source.
# Processed 1;github.com/barak-itkin/archaide-software from source.
# Processed 1;github.com/nkszjx/SSCDnet from source.
# Processed 15;github.com/Hoohm/CITE-seq-Count from source.
# Processed 1;github.com/Nils134/PRNG from source.
# Processed 1;github.com/googleinterns/wss from source.
# Processed 1;github.com/omkar2810/Inclusion_Exclusion_Phrase_Mining from source.
# Processed 2;github.com/KellerJordan/ResNet-PyTorch-CIFAR10 from source.
# Processed 1;github.com/stefanotoole/N-CPL from source.
# Processed 1;github.com/jtaylor351/queer_hci_slr from source.
# Processed 1;github.com/imls-measuring-up/ramp-analyses-scripts from source.
# Processed 1;github.com/lmbneuron/D-LMBmap from source.
# Processed 1;github.com/lmbneuron/D-LMBmap from source.
# Processed 1;github.com/andreyto/mgsat from source.
# Processed 1;github.com/molstar/rcsb-molstar from source.
# Processed 1;github.com/nkschaefer/sarge from source.
# Processed 1;github.com/TebaldiLab/eCLIP_seq from source.
# Processed 1;github.com/mihaioltean/traceless-genetic-programming from source.
# Processed 1;github.com/krishprince/dirart from source.
# Processed 5;github.com/XifengGuo/CapsNet-Keras from source.
# Processed 1;github.com/ISU-UBC/clinic-list-BC from source.
# Processed 2;github.com/pipelinedb/pipelinedb from source.
# Processed 1;github.com/WengLab-InformaticsResearch/COVID19-TrialFinder from source.
# Processed 1;github.com/SNU-LIST/chi-separation from source.
# Processed 1;github.com/flairNLP/flair from source.
# Processed 1;github.com/dvyavna/2ord_contrast from source.
# Processed 1;github.com/hsainnos/LICSTER from source.
# Processed 3;github.com/gangwug/SkinPhaser from source.
# Processed 2;github.com/yaozhong/deepIntraSV from source.
# Processed 1;github.com/sourcegraph/appdash from source.
# Processed 10;github.com/PaddlePaddle/PaddleDetection from source.
# Processed 3;github.com/cmmid/pcr-profile from source.
# Processed 2;github.com/AntSimi/py-eddy-tracker from source.
# Processed 1;github.com/nimh-mbdu/great_expectations from source.
# Processed 1;github.com/Pranav260/TMR from source.
# Processed 1;github.com/LLNL/metall from source.
# Processed 1;github.com/swing-research/xtdoa from source.
# Processed 1;github.com/Peccary-PMX/Peccary from source.
# Processed 1;github.com/SwayneLab/PFIA from source.
# Processed 1;github.com/tomayac/wikipedia-live-monitor from source.
# Processed 1;github.com/asaravia-butler/COV-IRT from source.
# Processed 2;github.com/tilleyd/cec2017-py from source.
# Processed 1;github.com/valentinitnelav/RandomScripts from source.
# Processed 1;github.com/ConstantinSeibold/SGL from source.
# Processed 1;github.com/garber-lab/inDrop_Processing from source.
# Processed 3;github.com/schmeing/ReSeq-paper from source.
# Processed 1;github.com/HHalva/hmnlica from source.
# Processed 2;github.com/neurohazardous/binauralBeats from source.
# Processed 1;github.com/jesus-333/FBCSP-Python from source.
# Processed 1;github.com/TheSatoLab/BA.2_related_Omicrons from source.
# Processed 1;github.com/XuejiangGuo/scapGNN from source.
# Processed 1;github.com/bplank/multitasksemantics from source.
# Processed 2;github.com/sinaahmadi/klpt from source.
# Processed 1;github.com/Albuso0/mixture from source.
# Processed 1;github.com/gailg/rmap from source.
# Processed 1;github.com/danilprov/batch-bandits from source.
# Processed 10;github.com/NOAA-EMC/WW3 from source.
# Processed 1;github.com/mozillasecurity/dharma from source.
# Processed 1;github.com/landau-lab/ONT-sc-Splice from source.
# Processed 2;github.com/GMPavanLab/lipids-comparison from source.
# Processed 1;github.com/RonMcKay/UQGAN from source.
# Processed 1;github.com/nawalgao/GPPrefElicit from source.
# Processed 1;github.com/ANDRIANTSIORY/MSC-DBSCAN from source.
# Processed 1;github.com/jlabeit/parallel-divsufsort from source.
# Processed 2;github.com/mtanti/coco-caption from source.
# Processed 1;github.com/imaginationdykim/2022.CC from source.
# Processed 1;github.com/benjaminvdb/110kDBRD from source.
# Processed 1;github.com/mourisl/Rascaf from source.
# Processed 3;github.com/moabitcoin/ig65m-pytorch from source.
# Processed 1;github.com/facebookresearch/Horizon from source.
# Processed 1;github.com/aimi-bonn/Deeplasia from source.
# Processed 1;github.com/gyhandy/Text2Image-for-Detection from source.
# Processed 1;github.com/hecomi/uLipSync from source.
# Processed 1;github.com/Zihan-Liu-00/GraD--NeurIPS22 from source.
# Processed 1;github.com/rflynn/imgmin from source.
# Processed 1;github.com/datduong/classify-syndromic-faces from source.
# Skipping https://raw.githubusercontent.com/Penzolab/Data-analysis-of-Two-way-active/master/README.md due to timeout or connection error.
# Processed 1;github.com/bfsujason/bertalign from source.
# Processed 1;github.com/chmendoza/cspwave from source.
# Processed 1;github.com/rordenlab/dcm2niix from source.
# Processed 1;github.com/rordenlab/dcm2niix from source.
# Processed 1;github.com/rordenlab/dcm2niix from source.
# Processed 1;github.com/rordenlab/dcm2niix from source.
# Processed 1;github.com/rordenlab/dcm2niix from source.
# Processed 1;github.com/rordenlab/dcm2niix from source.
# Processed 1;github.com/rordenlab/dcm2niix from source.
# Processed 1;github.com/rordenlab/dcm2niix from source.
# Processed 1;github.com/r-spatial/s2 from source.
# Processed 4;github.com/maraujo/pySocialWatcher from source.
# Processed 1;github.com/therneau/survival from source.
# Processed 1;github.com/therneau/survival from source.
# Processed 1;github.com/therneau/survival from source.
# Processed 1;github.com/therneau/survival from source.
# Processed 1;github.com/therneau/survival from source.
# Processed 1;github.com/therneau/survival from source.
# Processed 1;github.com/therneau/survival from source.
# Processed 1;github.com/archettialberto/tilebased_navigation_datasets from source.
# Processed 1;github.com/kwathen/OCTOPUS from source.
# Processed 4;github.com/chanzuckerberg/idseq-workflows from source.
# Processed 1;github.com/ssc-oscar/oscar.py from source.
# Processed 1;github.com/joyanujoy/geolib from source.
# Processed 2;github.com/AllenInstitute/asap-modules from source.
# Processed 1;github.com/emilyolafson/dynamic-brainstates from source.
# Processed 8;github.com/meom-group/CDFTOOLS from source.
# Processed 1;github.com/BU-ISCIII/WGS-Outbreaker from source.
# Processed 1;github.com/Fitz-like-coding/CWTM from source.
# Processed 8;github.com/vlawhern/arl-eegmodels from source.
# Processed 1;github.com/charlottegiseleweil/natcap_viz_toolbox from source.
# Processed 2;github.com/VariantEffect/rapimave from source.
# Processed 1;github.com/dcastrocamilo/EVAChallenge2019 from source.
# Processed 1;github.com/lhqing/snmCAT-seq_integration from source.
# Processed 1;github.com/xiaoyu258/DocProj from source.
# Processed 1;github.com/ASprae/Dynamic-Strength-and-Fragmentation from source.
# Processed 1;github.com/qui1712/spectroastrometry_pub from source.
# Processed 1;github.com/EliGurarie/memorymigration from source.
# Processed 1;github.com/hyounesy/bioc2016.visrseq from source.
# Processed 1;github.com/brain-life/app-ensembletracking from source.
# Processed 1;github.com/hub-se/jpf-shadow from source.
# Processed 1;github.com/currentslab/fastlangid from source.
# Processed 3;github.com/maksimhorowitz/nflscrapR from source.
# Processed 1;github.com/dmis-lab/KitchenScale from source.
# Processed 1;github.com/krasnowlab/HLCA from source.
# Processed 1;github.com/workforai/GSFM from source.
# Processed 9;github.com/ruotianluo/self-critical.pytorch from source.
# Processed 1;github.com/ForoughA/recursiveMemNet from source.
# Processed 2;github.com/cbc-casper/cbc-casper-paper from source.
# Processed 1;github.com/ctheissen/NIRSPEC-Data-Reduction-Pipeline from source.
# Processed 1;github.com/fcamilli95/Structured-PCA- from source.
# Processed 1;github.com/ucsdarclab/fastron from source.
# Processed 1;github.com/owang/BilateralVideoSegmentation from source.
# Processed 1;github.com/Emma926/mcbench from source.
# Processed 1;github.com/asappresearch/dialog-intent-induction from source.
# Processed 1;github.com/maxe-team/maxe from source.
# Processed 1;github.com/PreMedKB/PAnno from source.
# Processed 1;github.com/kipkurui/MARSTools from source.
# Processed 1;github.com/mpavlou/samplesizedev from source.
# Processed 1;github.com/mpavlou/samplesizedev from source.
# Processed 3;github.com/luetge/flagser from source.
# Processed 10;github.com/merlyescalona/yagcloser from source.
# Processed 1;github.com/zhezhaozoe/thanos from source.
# Processed 5;github.com/fidelram/deepTools from source.
# Processed 1;github.com/Eclipsess/CHIP_NeurIPS2021 from source.
# Processed 2;github.com/armartin/ancestry_pipeline from source.
# Processed 1;github.com/pfdominey/DiscourseOverrule from source.
# Processed 7;github.com/huggingface/swift-coreml-transformers from source.
# Processed 1;github.com/robot-perception-group/airship_simulation from source.
# Processed 6;github.com/ryanlayer/giggle from source.
# Processed 1;github.com/fabio-deep/Distributed-Pytorch-Boilerplate from source.
# Processed 1;github.com/joshpelkey/cmap-parse from source.
# Processed 2;github.com/OrganicityEu/JAMAiCA from source.
# Processed 1;github.com/loavila/mppt-gym from source.
# Processed 1;github.com/JustaTinyDot/BiTr-Unet from source.
# Processed 2;github.com/nghorbani/amass from source.
# Processed 1;github.com/achattaraj/maximal_Solubility_product from source.
# Processed 2;github.com/Ray-rui/Dist-PU-Positive-Unlabeled-Learning-from-a-Label-Distribution-Perspective from source.
# Processed 1;github.com/Tuteja-Lab/MetrialGland-scRNA-seq from source.
# Processed 1;github.com/petedodd/mvregerr from source.
# Processed 1;github.com/gwinterstein/Cifu from source.
# Processed 2;github.com/nemesiscode/radtrancode from source.
# Processed 1;github.com/tracking-exposed/yttrex from source.
# Processed 1;github.com/chijianlei/SeqTrans from source.
# Processed 1;github.com/eaplatanios/jelly-bean-world from source.
# Processed 1;github.com/gitliver/HIVCPS from source.
# Processed 1;github.com/crowdgames/mdp-level-assembly from source.
# Processed 1;github.com/genomica-fciencias-unam/SOP from source.
# Processed 1;github.com/comilf/Supplemental-Movies-Used from source.
# Processed 1;github.com/ldbc/ldbc_graphalytics_platforms_graphblas from source.
# Processed 3;github.com/MazinLab/MKIDPipeline from source.
# Processed 1;github.com/tkichuk/MitER from source.
# Processed 6;github.com/irebollo/stomach_brain_Scripts from source.
# Processed 1;github.com/DrLachie/smchd1_coloc from source.
# Processed 2;github.com/tuetschek/ratpred from source.
# Processed 1;github.com/Michalychforever/CLASS_LVDM from source.
# Processed 1;github.com/martablangiardo/ExcessDeathsItaly from source.
# Processed 3;github.com/anfoss/HTPS_workflow from source.
# Processed 1;github.com/lguelzow/On-Stellar-Migration-from-the-Andromeda-Galaxy from source.
# Processed 1;github.com/maximek3/MIMIC-NLE from source.
# Processed 1;github.com/l3cube-pune/indic-nlp from source.
# Processed 1;github.com/libChEBI/libChEBIpy from source.
# Processed 1;github.com/wyartlab/eLife_2019_OriginAndRole from source.
# Processed 3;github.com/pillar-markup/pillar from source.
# Processed 1;github.com/liulab-dfci/Degradability2021 from source.
# Processed 1;github.com/ksawatzki/H5N1_EID from source.
# Processed 1;github.com/camilla-ip/poremap from source.
# Processed 2;github.com/njahn82/semscholar from source.
# Processed 1;github.com/sTechLab/VoterFraud2020 from source.
# Processed 1;github.com/sTechLab/VoterFraud2020 from source.
# Processed 1;github.com/jackielinxiao/TPM from source.
# Processed 1;github.com/juliohvr/TurmellMetre0.1 from source.
# Processed 1;github.com/Bastlynn/bs-detector from source.
# Processed 1;github.com/gi0na/r-ghypernet from source.
# Processed 1;github.com/im-ethz/wave from source.
# Processed 1;github.com/JinjunGao/SESTAR from source.
# Processed 1;github.com/ISO-TC211/GOM from source.
# Processed 1;github.com/inesCompleto/Hippocampal_Plasticity from source.
# Processed 1;github.com/xiaolng/healpixSelector from source.
# Processed 1;github.com/ShortVideoRecommendation/Kuaishou-Video from source.
# Processed 1;github.com/DCGenomics/DangerTrack from source.
# Processed 2;github.com/asierzaragoza/flex2 from source.
# Processed 1;github.com/leondap/iodatabase from source.
# Processed 1;github.com/MDverse/mdde from source.
# Processed 1;github.com/Unispac/Fight-Poison-With-Poison from source.
# Processed 2;github.com/giacomo-janson/idpsam from source.
# Processed 1;github.com/ahclab/si_chunker from source.
# Processed 1;github.com/t-sakashita/rokko from source.
# Processed 2;github.com/ievron/wltls from source.
# Processed 2;github.com/tushartushar/Puppeteer from source.
# Processed 1;github.com/coleifer/sqlite-web from source.
# Processed 1;github.com/YX-IBE/AMLTimeDependentSimulation from source.
# Processed 1;github.com/songbo446/slORFfinder from source.
# Processed 1;github.com/rdmpage/bionames from source.
# Processed 1;github.com/conda-forge/autorift-feedstock from source.
# Processed 1;github.com/USDA-VS/GenoFLU from source.
# Processed 1;github.com/stop-pre16/Li-ERJ-Supplemental-Tables from source.
# Processed 1;github.com/microsoft/SimXNS from source.
# Processed 5;github.com/Coder-Yu/QRec from source.
# Processed 13;github.com/DeepGraphLearning/KnowledgeGraphEmbedding from source.
# Processed 3;github.com/josephryan/SOWHAT from source.
# Processed 1;github.com/mschiffn/rhombic_grids from source.
# Processed 1;github.com/davidaray/bioinfotools from source.
# Processed 1;github.com/bvernot/freezing-archer from source.
# Processed 1;github.com/bvernot/freezing-archer from source.
# Processed 1;github.com/Tencent/DVQA from source.
# Processed 1;github.com/Astroua/AstroStat_Results from source.
# Processed 1;github.com/hazemalsaied/ATILF-LLF.v2 from source.
# Processed 1;github.com/xhu248/AutoSAM from source.
# Processed 1;github.com/alexwjung/ProbCox from source.
# Processed 1;github.com/rest-for-physics/restG4 from source.
# Processed 1;github.com/rxlian/LA-SCL from source.
# Processed 1;github.com/a2i2/threshy from source.
# Processed 1;github.com/careslab/DVRK_RecordAndPlayback from source.
# Processed 1;github.com/Georgerun/NeuroKinModel from source.
# Processed 1;github.com/MartijnGosgens/mobility-forecasting-covid from source.
# Processed 1;github.com/welinder/cubam from source.
# Processed 1;github.com/ulgenklc/Neuronal_Cascades from source.
# Processed 1;github.com/GT-NucleicAcids/pnab from source.
# Processed 1;github.com/mcmero/SVclone_Rmarkdown from source.
# Processed 1;github.com/vsergeev/c-periphery from source.
# Processed 1;github.com/BY571/FQF-and-Extensions from source.
# Processed 1;github.com/PapenfussLab/endiaQC from source.
# Processed 1;github.com/wanqingshao/TE_expression_in_scRNAseq from source.
# Processed 1;github.com/python-pillow/pillow from source.
# Processed 1;github.com/gangweiX/ACVNet from source.
# Processed 2;github.com/dbrg77/plate_scATAC-seq from source.
# Processed 1;github.com/fogleman/gg from source.
# Processed 1;github.com/ucdscenter/Covid_Network_Bridges_code from source.
# Processed 2;github.com/MJTemple/qsogen from source.
# Processed 1;github.com/cssblab/iOmicsPASSplus from source.
# Processed 1;github.com/ashispati/ar-vae from source.
# Processed 1;github.com/soumith/DeepLearningFrameworks from source.
# Processed 1;github.com/IBM/DPFS from source.
# Processed 2;github.com/cu-clear/verbnet from source.
# Processed 2;github.com/biostatUniBS/BS_EWS from source.
# Processed 1;github.com/hpiwowar/citation11k from source.
# Processed 1;github.com/Behnam-Shobiri/CDN-Finder from source.
# Processed 1;github.com/nataliehogg/analosis from source.
# Processed 1;github.com/tue-mps/damiirl from source.
# Processed 1;github.com/mirabelreid/Assemblies-Simulations from source.
# Processed 1;github.com/Adamtaranto/teloclip from source.
# Processed 1;github.com/Adamtaranto/teloclip from source.
# Processed 1;github.com/negrinho/deep_architect from source.
# Processed 1;github.com/Fortyseven/ToneDef from source.
# Processed 41;github.com/raghakot/keras-vis from source.
# Processed 10;github.com/opencv/opencv-python from source.
# Processed 1;github.com/amkozlov/raxml-ng from source.
# Processed 1;github.com/amkozlov/raxml-ng from source.
# Processed 1;github.com/amkozlov/raxml-ng from source.
# Processed 1;github.com/amkozlov/raxml-ng from source.
# Processed 1;github.com/jiang-du/Perceptual-CS from source.
# Processed 1;github.com/Noro-COVID-Rollins/NPI-Noro-COVID from source.
# Processed 1;github.com/james-cole/brainageR from source.
# Processed 1;github.com/james-cole/brainageR from source.
# Processed 2;github.com/AlexTS1980/COVID-Affinity-Model from source.
# Processed 1;github.com/jlstiles/blipCDF from source.
# Processed 1;github.com/gulcinbaykal/DeshuffleGAN from source.
# Processed 1;github.com/masaomi-yamaguchi/synbit from source.
# Processed 1;github.com/cdancette/spatial-counting-network from source.
# Processed 1;github.com/cae67/Fuzzy_Clustering from source.
# Processed 1;github.com/cerndb/hloader from source.
# Processed 1;github.com/steverozen/SynSigGen from source.
# Processed 1;github.com/IronCoreLabs/recrypt-rs from source.
# Processed 1;github.com/holtskinner/PossibilisticCMeans from source.
# Processed 1;github.com/qa276390/SearchTrack from source.
# Processed 1;github.com/CompEpigen/figeno from source.
# Processed 2;github.com/mattya/chainer-DCGAN from source.
# Processed 1;github.com/afDursun/Kyber-PAKE-Mobile from source.
# Processed 1;github.com/erelsgl/ordinal-maximin-share from source.
# Processed 1;github.com/yujun0-0/MMA-Net from source.
# Processed 3;github.com/angusleigh/leg_tracker from source.
# Processed 1;github.com/foobar-land/coq-of-ocaml from source.
# Processed 1;github.com/divya031090/TaxoNN_OTU from source.
# Processed 1;github.com/MarcOedingen/Iterative-Oblique-Decision-Trees from source.
# Processed 1;github.com/sebalamm/KaGen from source.
# Processed 1;github.com/chiaramff/IronTract from source.
# Processed 1;github.com/aakhmetz/Mpox-IncubationPeriodSerialInterval-Meta2023 from source.
# Processed 1;github.com/ICONgroupCWC/Demo.Percom23 from source.
# Processed 1;github.com/tomsumner/Variance_SA_TB from source.
# Processed 20;github.com/optuna/optuna from source.
# Processed 1;github.com/ysaikai/case4fbo from source.
# Processed 1;github.com/WENGSYX/Self-Verification from source.
# Processed 1;github.com/Kotlin/kotlinx.coroutines from source.
# Processed 1;github.com/sarnthil/unify-emotion-datasets from source.
# Processed 1;github.com/ahmad-taie/infodens from source.
# Processed 1;github.com/bayramakdeniz/Finemap-MiXeR from source.
# Processed 1;github.com/ce-carey/ukb-factor-analysis from source.
# Processed 1;github.com/ce-carey/ukb-factor-analysis from source.
# Processed 1;github.com/ce-carey/ukb-factor-analysis from source.
# Processed 2;github.com/amices/mice from source.
# Processed 1;github.com/ELEKTRONN/elektronn3 from source.
# Processed 1;github.com/ELEKTRONN/elektronn3 from source.
# Processed 16;github.com/linkedin/luminol from source.
# Processed 1;github.com/amr-turkish/turkish-amr-guidelines from source.
# Processed 1;github.com/xingyf14/CRYSTALS-KYBER from source.
# Processed 1;github.com/Datalab-AUTH/LifeSnaps-EDA from source.
# Processed 1;github.com/sajidhasanapon/NS2 from source.
# Processed 1;github.com/thaije/code-to-comment from source.
# Processed 6;github.com/numpi/hm-toolbox from source.
# Processed 2;github.com/WeisiX/ITAS3D from source.
# Processed 34;github.com/nanopore-wgs-consortium/NA12878 from source.
# Processed 1;github.com/msmbuilder/msmbuilder from source.
# Processed 1;github.com/tianxintao/get_up_control from source.
# Processed 16;github.com/tflearn/tflearn from source.
# Processed 1;github.com/ylunalin/BacSim-T6SS from source.
# Processed 1;github.com/sigbjobo/hPF_MD_PMESH from source.
# Processed 3;github.com/brittonsmith/cloudy_cooling_tools from source.
# Processed 1;github.com/ismaRP/a_spanish_book from source.
# Processed 1;github.com/sidchaini/MargNet from source.
# Processed 1;github.com/AutomatedProcessImprovement/log-distance-measures from source.
# Processed 1;github.com/reykeryao/FLEXI from source.
# Processed 1;github.com/AlvaroGI/optimal-homogeneous-chain from source.
# Processed 1;github.com/AlvaroGI/optimal-homogeneous-chain from source.
# Processed 1;github.com/Acnext/Optical-Flow-For-Spiking-Camera from source.
# Processed 1;github.com/kukionfr/VAMPIRE_open from source.
# Processed 1;github.com/ModECI/MDF from source.
# Processed 1;github.com/ModECI/MDF from source.
# Processed 1;github.com/ruberhg/SoftVein-WELM from source.
# Processed 1;github.com/Xipeng-Chen/DWSL-3D-pose from source.
# Processed 1;github.com/benjaminviart/PickPocket from source.
# Processed 1;github.com/shenwanxiang/ChemBench from source.
# Processed 1;github.com/openconnectome/ReconstructImport from source.
# Processed 2;github.com/hocinebib/PisaPy from source.
# Processed 1;github.com/parantes/rhythm from source.
# Processed 1;github.com/hauserrg/GraphicalGuidelines from source.
# Processed 2;github.com/laurenchilds/GC from source.
# Processed 1;github.com/celaoforever/SHEsisPlus from source.
# Processed 1;github.com/xuyu-cam/PGS-BC-Traits-Using-ML-DL from source.
# Processed 1;github.com/copenlu/slavic-gender-bias from source.
# Processed 1;github.com/wangunji/POI-data-of-China from source.
# Processed 1;github.com/DrYGuo/STS from source.
# Processed 2;github.com/Guzaiwang/CE-Net from source.
# Processed 1;github.com/lancercat/OSOCR from source.
# Processed 1;github.com/sandropezzelle/multitask-quant from source.
# Processed 1;github.com/jorisBarkema/Graphene-Editor from source.
# Processed 1;github.com/bambinos/formulae from source.
# Processed 1;github.com/diyclassics/la_core_web_lg from source.
# Processed 1;github.com/VITA-Group/AutoGAN from source.
# Processed 4;github.com/CDCgov/datasets-sars-cov-2 from source.
# Processed 1;github.com/pnlbwh/dMRIharmonization from source.
# Processed 1;github.com/ncss-tech/compare-psm from source.
# Processed 1;github.com/CINPLA/hdf5-exdir-converter from source.
# Processed 3;github.com/mtisza1/Cenote-Taker from source.
# Processed 1;github.com/firehol/netdata from source.
# Processed 2;github.com/cambridge-mlg/DUN from source.
# Processed 1;github.com/george-fedorov/erp-correlations from source.
# Processed 1;github.com/BogdanBintu/ChromatinImaging from source.
# Processed 1;github.com/LACourtenay/Support-Vector-Machine-for-Morphological-Analysis from source.
# Processed 2;github.com/EPPIcenter/flexfit from source.
# Processed 1;github.com/Subhayan18/CRUST from source.
# Processed 1;github.com/Agricultural-Robotics-Bonn/visual-multi-crop-row-navigation from source.
# Processed 1;github.com/Zhendong-Wang/Probabilistic-Conformal-Prediction from source.
# Processed 1;github.com/TolgaOk/Differentiable-Hard-Attention-Module from source.
# Processed 1;github.com/denisagniel/crossurr from source.
# Processed 2;github.com/Jaybro/pico_tree from source.
# Processed 1;github.com/ethereum/fe from source.
# Processed 1;github.com/luislizcano/3D-wetlands-app from source.
# Processed 1;github.com/Sakibsourav019/UBMEC-Unified-Bangla-Multi-class-Emotion-Corpus- from source.
# Processed 1;github.com/wesleyburr/bias-in-estimation from source.
# Processed 2;github.com/Ligophorus/RandomTaPas from source.
# Processed 1;github.com/RUB-NDS/PRET from source.
# Processed 3;github.com/jiemakel/omorfi from source.
# Processed 1;github.com/gyauney/data-similarity-is-not-enough from source.
# Processed 1;github.com/CQCL/pytket-dqc from source.
# Processed 1;github.com/fjiangAI/CPTS from source.
# Processed 1;github.com/fmtlib/fmt from source.
# Processed 1;github.com/soumickmj/MRUnder from source.
# Processed 1;github.com/asvd/jailed from source.
# Processed 1;github.com/geonlee0325/THyMe from source.
# Processed 2;github.com/linzh92/DeepICF from source.
# Processed 1;github.com/brainML/great-apes from source.
# Processed 1;github.com/henrygouk/stochastic-gradient-trees from source.
# Processed 1;github.com/JChander/DeepMiR2GO from source.
# Processed 3;github.com/twairball/gams-dataset from source.
# Processed 1;github.com/NeuroenergeticsLab/control_costs from source.
# Processed 1;github.com/rccohn/NEU-Cluster from source.
# Processed 1;github.com/NKI-CCB/ggsea from source.
# Processed 1;github.com/ongardie/raft.tla from source.
# Processed 1;github.com/ropensci/geojsonio from source.
# Processed 3;github.com/hbldh/pyefd from source.
# Processed 1;github.com/RawadB01/SGC from source.
# Processed 2;github.com/AskNowQA/SQG from source.
# Processed 1;github.com/MacIver-Lab/gridworld-decisionmaking from source.
# Processed 1;github.com/xiaohong1/COVID-ViT from source.
# Processed 1;github.com/lim1014/DeepPrevention from source.
# Processed 1;github.com/trichter/qopen_finland from source.
# Processed 1;github.com/databio/refgenie from source.
# Processed 1;github.com/databio/refgenie from source.
# Processed 2;github.com/l3das/L3DAS21 from source.
# Processed 1;github.com/cedrikschueler/PARRoT from source.
# Processed 4;github.com/bacanusa/FIQT from source.
# Processed 1;github.com/nh2tran/DeepNovo-DIA from source.
# Processed 1;github.com/klovbe/scSDAE from source.
# Processed 1;github.com/UKPLab/coling2018-wcs from source.
# Processed 1;github.com/egri-nagy/lambdago from source.
# Processed 1;github.com/meco-group/mecotron from source.
# Processed 1;github.com/cchrewrite/SLDR-DL from source.
# Processed 1;github.com/floledermann/mapmap.js from source.
# Processed 1;github.com/damian-quijano/identify_nationality_twitter from source.
# Processed 1;github.com/UMCUGenetics/Bovine_Embryo from source.
# Processed 1;github.com/SimonLab-RU/Puncta-Fit from source.
# Processed 3;github.com/CrayLabs/SmartSim from source.
# Processed 1;github.com/jiangdat/COMI from source.
# Processed 1;github.com/jwallat/knowledge-probing from source.
# Processed 1;github.com/lamm-mit/GraphGeneration from source.
# Processed 2;github.com/Hughes-Genome-Group/CIView from source.
# Processed 1;github.com/xindd/DCNet from source.
# Processed 1;github.com/nicklally/shaping from source.
# Processed 1;github.com/v-julia/coronavirus_recombination from source.
# Processed 1;github.com/t-momozaki/RORM from source.
# Processed 3;github.com/supereggbert/proctree.js from source.
# Processed 1;github.com/xinario/SAGAN from source.
# Processed 1;github.com/rsingha108/TransLIST from source.
# Processed 1;github.com/cleopatra-itn/BarrierDetection-Classification from source.
# Processed 2;github.com/keyajoshi/Pan_response from source.
# Processed 1;github.com/lauringlab/MFE_paper from source.
# Processed 1;github.com/yxchspring/GOEGCN_BRCA_Subtypes from source.
# Processed 1;github.com/julieefeusier/IGV-Batch-Script-Generator-for-bed-files from source.
# Processed 1;github.com/lu-group/mionet from source.
# Processed 1;github.com/FG-TUM/OrbitPropagator from source.
# Processed 1;github.com/amaas/stanford-ctc from source.
# Processed 1;github.com/petephilipson/MPCMP_Test_bowlers from source.
# Processed 3;github.com/nicost/MMClearVolumePlugin from source.
# Processed 1;github.com/jingnantes/AnnotationModel from source.
# Processed 3;github.com/MMAP/MMAP.github.io from source.
# Processed 1;github.com/NeuralNimbus/Beyond-Retrieval from source.
# Processed 1;github.com/rochoa85/data-Biomolecules-Kinases from source.
# Processed 1;github.com/CMUSchwartzLab/RADs from source.
# Processed 1;github.com/olafmersmann/truncnorm from source.
# Processed 2;github.com/coltonlloyd/OptAux from source.
# Processed 2;github.com/esauta/TBN_learning from source.
# Processed 3;github.com/MichelleLochner/astronomaly from source.
# Processed 1;github.com/broadinstitute/adapt-seq-design from source.
# Processed 2;github.com/dms-view/dms-view.github.io from source.
# Processed 2;github.com/facebookresearch/neural-rewriter from source.
# Processed 1;github.com/594422814/ContrastCorr from source.
# Processed 2;github.com/mosdef-hub/foyer from source.
# Processed 1;github.com/Henningston/ABMs from source.
# Processed 1;github.com/moghbaie/NCBP-pipeline from source.
# Processed 1;github.com/zhoumumu/VapSR from source.
# Processed 1;github.com/OlgaMMC/iGED_new_repo from source.
# Processed 2;github.com/ksj7924/CLBCat from source.
# Processed 1;github.com/KeremTurgutlu/clip_art from source.
# Processed 1;github.com/Core-Bioinformatics/IonescuNicaise2023 from source.
# Processed 1;github.com/Systems-Immunology-IKMB/COVIDOMICs from source.
# Processed 1;github.com/wyx2012/BG-DTI from source.
# Processed 93;github.com/marbl/canu from source.
# Processed 1;github.com/MathiasKraus/FinancialDeepLearning from source.
# Processed 3;github.com/dgleich/mlpagerank from source.
# Processed 1;github.com/anirudhtomer/JMbayes from source.
# Processed 2;github.com/scrna-seq/TASC from source.
# Processed 1;github.com/ZhangTT-race/CVPR2020-MultiModal from source.
# Processed 1;github.com/yguo0102/Fontan_classification from source.
# Processed 1;github.com/meisaputri21/Indonesian-Twitter-Emotion-Dataset from source.
# Processed 1;github.com/GAA-UAM/GBNN from source.
# Processed 1;github.com/qingxinsong/single_cell from source.
# Processed 1;github.com/nilc-nlp/AMR-BP from source.
# Processed 1;github.com/LivingPark-MRI/livingpark-utils from source.
# Processed 1;github.com/mlubin/JuMPChance.jl from source.
# Processed 4;github.com/fortunatobianconi/CRC from source.
# Processed 1;github.com/radekszostak/aerial-thermal-tuner from source.
# Processed 2;github.com/tamuri/tdg09 from source.
# Processed 1;github.com/hyz-xmaster/VarifocalNet from source.
# Processed 1;github.com/ZhihaoChe/MAFF-HRNet from source.
# Processed 1;github.com/AVSystem/Anjay from source.
# Processed 1;github.com/tcezard/RADmapper from source.
# Processed 1;github.com/rohan-shah/mpMap2 from source.
# Processed 61;github.com/Lyken17/pytorch-OpCounter from source.
# Processed 1;github.com/rasigadelab/metapop from source.
# Processed 3;github.com/nodeca/pako from source.
# Processed 1;github.com/bitcoinjs/bitcoinjs-lib from source.
# Processed 1;github.com/mlfoundations/task_vectors from source.
# Processed 2;github.com/dlunion/DBFace from source.
# Processed 1;github.com/HkeyHKey/Hebras_et_al_2020 from source.
# Processed 1;github.com/esteinig/brigD3 from source.
# Processed 1;github.com/aitor-martinez-seras/OoD_on_SNNs from source.
# Processed 1;github.com/szeighami/SNH from source.
# Processed 1;github.com/emited/flow from source.
# Processed 1;github.com/Tarotis/Building-an-Endangered-Language-Resource-in-the-Classroom from source.
# Processed 2;github.com/InternLM/InternLM-techreport from source.
# Processed 1;github.com/davidmhart/SelectionConv from source.
# Processed 1;github.com/Megum1/BEAGLE from source.
# Processed 1;github.com/BatadaLab/scID_manuscript_figures from source.
# Processed 3;github.com/fraser-lab/EMRinger from source.
# Processed 1;github.com/abhisuri97/SpineTK from source.
# Processed 1;github.com/XRPLF/rippled from source.
# Processed 1;github.com/jennhu/metalinguistic-prompting from source.
# Processed 1;github.com/glnmario/emo2vec from source.
# Processed 1;github.com/TomasCast/sipaim-2022-resnet from source.
# Processed 1;github.com/hhucn/discuss from source.
# Processed 1;github.com/R-niamh/IBD_analysis from source.
# Processed 1;github.com/okada-lab/exhbma from source.
# Processed 1;github.com/jostmey/MaxSnippetModelOvarian from source.
# Processed 1;github.com/wenwu-tang/agentlcm from source.
# Processed 2;github.com/vanvalenlab/deepcell-spots from source.
# Processed 2;github.com/vanvalenlab/deepcell-spots from source.
# Processed 1;github.com/madsys-dev/sosp-paper19-ae from source.
# Processed 1;github.com/vargas-garcia/Glyma.18G026900 from source.
# Processed 1;github.com/lipan6461188/icSHAPE-pipe from source.
# Processed 2;github.com/romainsacchi/rmnd-lca from source.
# Processed 1;github.com/YijingXin0/code from source.
# Processed 2;github.com/coin-or/Clp from source.
# Processed 1;github.com/aysafanxm/llm_code_tracing_question_generation from source.
# Processed 1;github.com/beckrob/AvERA_ISW from source.
# Processed 1;github.com/SauronGuide/corpusABG from source.
# Processed 1;github.com/AljazBozic/TransformerFusion from source.
# Processed 1;github.com/JDRomano2/venomkb from source.
# Processed 1;github.com/zjukg/AnKGE from source.
# Processed 1;github.com/FourierFlows/FourierFlows.jl from source.
# Processed 1;github.com/openUC2/UC2-STORM-and-Fluorescence from source.
# Processed 1;github.com/alvaro-martin/data-sience-for-covid19 from source.
# Processed 1;github.com/mpross/CRS-Schematics from source.
# Processed 1;github.com/longkangli/PFSS-IL from source.
# Processed 1;github.com/shangruJia/scDeepInsight-additional from source.
# Processed 1;github.com/alexlee-gk/visual_dynamics from source.
# Processed 1;github.com/isovic/samscripts from source.
# Processed 1;github.com/SDM-TIB/falcon2.0 from source.
# Processed 1;github.com/BWGZK/ShapePU from source.
# Processed 3;github.com/libbi/RBi from source.
# Processed 1;github.com/MANDO-Project/ge-sc from source.
# Processed 1;github.com/shiliyan/nanopolish from source.
# Processed 1;github.com/zhaoyue-zephyrus/AVION from source.
# Processed 2;github.com/shyam196/egc from source.
# ...
# Processed 1;github.com/potassco/asprilo-encodings from source.
# Processed 2;github.com/romain-jacob/triscale from source.
# Processed 1;github.com/juangamella/icp from source.
# Processed 2;github.com/ApolloDev/apollo-sv from source.
# Processed 1;github.com/JiangFangzhou/SIDM from source.
# Processed 1;github.com/smkia/DNM from source.
# Processed 1;github.com/tansey-lab/pdbal from source.
# Processed 1;github.com/JunfengGaolab/Counting-Aphids from source.
# Processed 1;github.com/Salehi-Khayyam/Channel-Capacity from source.
# Processed 1;github.com/GX77/Dual-Stream-Transformer-for-Generic-Event-Boundary-Captioning from source.
# Processed 1;github.com/hcai-mms/ProtoMF from source.
# Processed 1;github.com/JunhoJeon/interval_gradient from source.
# Processed 1;github.com/immunant/c2rust from source.
# Processed 1;github.com/choldgraf/UCSF-Data_Driven_Neuro from source.
# Processed 1;github.com/khakhalin/Xenopus-Behavior from source.
# Processed 1;github.com/khakhalin/Xenopus-Behavior from source.
# Processed 1;github.com/khakhalin/Xenopus-Behavior from source.
# Processed 1;github.com/alexanderrobitzsch/TAM from source.
# Processed 1;github.com/eval4nlp/SharedTask2021 from source.
# Processed 1;github.com/Lifelong-ML/Mendez2022ModularLifelongRL from source.
# Processed 1;github.com/janis10/evrostos from source.
# Processed 2;github.com/NuoLiLabBCM/Autocage from source.
# Processed 1;github.com/facebookresearch/TaBERT from source.
# Processed 1;github.com/CMU-CBML/SRL-AssistedAFM from source.
# Processed 1;github.com/tsinghua-fib-lab/DGCN from source.
# Processed 1;github.com/korpuskel91/pomato from source.
# Processed 1;github.com/trambakbanerjee/ASUS from source.
# Processed 1;github.com/vickerse1/mesoscope_spontaneous from source.
# Processed 1;github.com/GuanLab/ciclops from source.
# Processed 1;github.com/farlit/ACDS from source.
# Processed 2;github.com/raux/PomWalker from source.
# Processed 1;github.com/mcoavoux/SCAN_syntax from source.
# Processed 1;github.com/RSNA/s4s-fhir-broker from source.
# Processed 1;github.com/MattCocci/FredFetch from source.
# Processed 1;github.com/tunazislam/Covid_FB_AD_MinimalSup from source.
# Processed 3;github.com/zhoujp111/DMDtoolkit from source.
# Processed 2;github.com/bioinformatics-ua/scaleus-fair from source.
# Processed 1;github.com/DemocracyEarth/sovereign from source.
# Processed 2;github.com/google-research-datasets/great from source.
# Processed 1;github.com/SjoerdVBeentjes/ripleyk from source.
# Processed 1;github.com/hickslab/QuantifyR from source.
# Processed 1;github.com/hickslab/QuantifyR from source.
# Processed 1;github.com/Kenizzer/California_Transect_Microbiome from source.
# Processed 1;github.com/wen571/PAMscore from source.
# Processed 1;github.com/wen571/PAMscore from source.
# Processed 1;github.com/inQWIRE/QuantumLib from source.
# Processed 1;github.com/alishakiba/Correlation-Clustering-Algorithm-for-Dynamic-Complete-Signed-Graphs-An-Index-based-Approach from source.
# Processed 1;github.com/reddyav1/RoCoG-v2 from source.
# Processed 1;github.com/joechenUNSW/gadget4-supereasy from source.
# Processed 1;github.com/neo4j-graphql/neo4j-graphql-js from source.
# Processed 1;github.com/eurypt/MEG-UPDRS from source.
# Processed 1;github.com/MCour/DiSuGen from source.
# Processed 2;github.com/mummi-framework/mummi-ras from source.
# Processed 1;github.com/alialavia/binson from source.
# Processed 1;github.com/BruceWen120/medal from source.
# Processed 1;github.com/massimilianotamborrino/shotnoise from source.
# Processed 3;github.com/ITBE-Lab/seed-evaluation from source.
# Processed 1;github.com/Molmed/REH from source.
# Processed 1;github.com/sra34/SkIOprotists from source.
# Processed 2;github.com/BingyaoHuang/SPAA from source.
# Processed 2;github.com/LukeSurl/WCV from source.
# Processed 1;github.com/sssomani/glp1_reddit from source.
# Processed 1;github.com/qcri/ArabicASRChallenge2016 from source.
# Processed 1;github.com/nicolaPedre/Temporal-Rich-Club from source.
# Processed 3;github.com/yanglab-emory/TIGAR from source.
# Processed 1;github.com/phdymz/ProteinMAE from source.
# Processed 1;github.com/Vrushabh27/High-Order-DO-ICBF from source.
# Processed 1;github.com/byaxb/recor from source.
# Processed 1;github.com/tse-group/pos-ghost-attack from source.
# Processed 1;github.com/semontesdeoca/MNPR from source.
# Processed 2;github.com/henchc/syllabipy from source.
# Processed 2;github.com/senresearch/LiteQTL.jl from source.
# Processed 2;github.com/douyimin/FaultNet from source.
# Processed 1;github.com/JoseCoboDiaz/piecharts_tax_st2 from source.
# Processed 2;github.com/newaetech/chipwhisperer from source.
# Processed 1;github.com/podesse/three-kepler-binaries-repo from source.
# Processed 5;github.com/yistLin/FragmentVC from source.
# Processed 1;github.com/nsj3/darleq3 from source.
# Processed 40;github.com/fizyr/keras-retinanet from source.
# Processed 4;github.com/mbarrere/meta4ics from source.
# Processed 1;github.com/kailaix/NNFEM.jl from source.
# Processed 2;github.com/eshoko/COMET from source.
# Processed 2;github.com/ppxasjsm/Geometric-constraints-protein-folding from source.
# Processed 2;github.com/tangzheng1/PSCAN from source.
# Processed 1;github.com/Traubert/FiNer-rules from source.
# Processed 1;github.com/zhanjunlang/Neural_Chemical_Name_Standardization from source.
# Processed 1;github.com/dengkuistat/WaveICA from source.
# Processed 1;github.com/JiaRui12345/CODE-DATA from source.
# Processed 1;github.com/thomasahle/numberlink from source.
# Processed 1;github.com/OIPLab-DUT/Deep-Light-Field-Depth-Estimation from source.
# Processed 5;github.com/nawrockie/vadr from source.
# Processed 1;github.com/Machine-Listeners-Valencia/seld-dcase2021 from source.
# Processed 1;github.com/yuezunli/celeb-deepfakeforensics from source.
# Processed 2;github.com/astawsky/Multiple-Timescales-in-Bacterial-Growth-Homeostasis from source.
# Processed 1;github.com/dfporter/easyCLIP from source.
# Processed 1;github.com/ifarup/anisotropic-daltonisation from source.
# Processed 1;github.com/SALT-NLP/normbank from source.
# Processed 1;github.com/RyanLiut/WSD-UE from source.
# Processed 1;github.com/qBioTurin/epischool-abm from source.
# Processed 1;github.com/yfliu088/GMAP from source.
# Processed 1;github.com/zpeng27/GMI from source.
# Processed 5;github.com/tevador/RandomX from source.
# Processed 1;github.com/aaryapatil/elicit-disk-copulas from source.
# Processed 1;github.com/C66YU/CSRN from source.
# Processed 1;github.com/shatrunjai/aed_pubmed from source.
# Processed 7;github.com/tshmak/lassosum from source.
# Processed 1;github.com/f-data/ADD from source.
# Processed 1;github.com/KDL-UMass/PlanAlyzer from source.
# Processed 1;github.com/youngseok-kim/BayesMSG-paper from source.
# Processed 1;github.com/dogmaphobic/mavesp8266 from source.
# Processed 1;github.com/ACI-Institute/faces4coco from source.
# Processed 1;github.com/nuochenpku/Orca from source.
# Processed 2;github.com/citronneur/rdpy from source.
# Processed 1;github.com/fa-bien/broute from source.
# Processed 1;github.com/HuanYingLi/Dataset-for-Risky-Driving-Detection from source.
# Processed 1;github.com/riccobelli/coiling-rod from source.
# Processed 1;github.com/ffzzy840304/Masked-PDPP from source.
# Processed 1;github.com/blajoie/tab2hdf from source.
# Processed 1;github.com/liyaguang/dcrnn from source.
# Processed 1;github.com/SydShafferLab/BarcodeAnalysis from source.
# Processed 1;github.com/jongwonJeong/FPAdaMetric from source.
# Processed 2;github.com/360netlab/DGA from source.
# Processed 1;github.com/ka-moamoa/interaction-harvesters from source.
# Processed 2;github.com/ccp-eva/AustroGames from source.
# Processed 1;github.com/adel-asadi/Christchurch_Augmented_Liquefaction from source.
# Processed 1;github.com/strongbeamsprout/Gene-Prioritization from source.
# Processed 1;github.com/tristanstoeber/CA2_spatiallearning from source.
# Processed 1;github.com/MaxJakobs/Nieuwburg2017 from source.
# Processed 1;github.com/Luca-Blum/Box-Cox-for-machine-learning from source.
# Processed 1;github.com/amireson/RichardsEquation from source.
# Processed 1;github.com/emilrosen/endpoint_cell_diffusion from source.
# Processed 1;github.com/emilrosen/endpoint_cell_diffusion from source.
# Processed 1;github.com/emilrosen/endpoint_cell_diffusion from source.
# Processed 12;github.com/broadinstitute/cromwell from source.
# Processed 1;github.com/HYH-yuhan/TumorID from source.
# Processed 1;github.com/HYH-yuhan/TumorID from source.
# Processed 1;github.com/iqtigorg/voloutsim from source.
# Processed 1;github.com/davidclark1/FastKF from source.
# Processed 1;github.com/leonardlab/GAMES from source.
# Processed 1;github.com/suinleelab/deepprofile-study from source.
# Processed 2;github.com/gcarq/rusty-blockparser from source.
# Processed 1;github.com/YoochanMyung/scripts from source.
# Processed 2;github.com/elifesciences-publications/2018_eLife_Alexander_et_al from source.
# Processed 2;github.com/pulimeng/etoxpred from source.
# Processed 2;github.com/rstudio/d3heatmap from source.
# Processed 1;github.com/thuchoang90/VexRiscv from source.
# Processed 1;github.com/Alexamk/decRiPPter from source.
# Processed 1;github.com/GitGears/CYP from source.
# Processed 1;github.com/RhettZhou/APT_GB from source.
# Processed 6;github.com/Adapter-Hub/adapter-transformers from source.
# Processed 1;github.com/tuttieee/lear-gist-python from source.
# Processed 1;github.com/franrruiz/shopper-src from source.
# Processed 1;github.com/jbiesanz/fabs from source.
# Processed 1;github.com/TadasBaltrusaitis/OpenFace from source.
# Processed 1;github.com/TadasBaltrusaitis/OpenFace from source.
# Processed 1;github.com/joeleaves/JDE.jl from source.
# Processed 3;github.com/irinagain/Awesome-CGM from source.
# Processed 1;github.com/tomas-cabrera/hvss-bsco from source.
# Processed 3;github.com/sunbeam-labs/sbx_template from source.
# Processed 1;github.com/maybec49/Antarctic_Fish_Viromes from source.
# Processed 2;github.com/doomlab/MeMoBootR from source.
# Processed 1;github.com/kaitlin309/PRIESSTESS from source.
# Processed 1;github.com/coldrainyht/caffe from source.
# Processed 5;github.com/rhuebler/HOPS from source.
# Processed 1;github.com/yzh119/BPT from source.
# Processed 3;github.com/kjgleason/Primo from source.
# Processed 1;github.com/boydorr/rdiversity from source.
# Processed 1;github.com/boun-tabi/chemboost from source.
# Processed 1;github.com/albytrav/RadiomicsOntologyIBSI from source.
# Processed 4;github.com/zhonge/cryodrgn from source.
# Processed 3;github.com/DiscreteTotalVariation/TVOR from source.
# Processed 1;github.com/valfride/lpr-rsr from source.
# Processed 1;github.com/embr/lsh from source.
# Processed 1;github.com/markowetzlab/pathml from source.
# Processed 1;github.com/google/cog from source.
# Processed 1;github.com/Pat-Laub/SLNOrthogonalPolynomials from source.
# Processed 1;github.com/CharafeddineMechalikh/PureEdgeSim from source.
# Processed 1;github.com/barinderbanwait/dihedral-newforms from source.
# Processed 1;github.com/Auledas/monitoring_aircraft_systems_data from source.
# Processed 1;github.com/yulearningg/LRDG from source.
# Processed 2;github.com/jepusto/scdhlm from source.
# Processed 1;github.com/tamaspapp/rwmcouplings from source.
# Processed 1;github.com/j-e-james/TreeDFEScripts from source.
# Processed 1;github.com/j-e-james/TreeDFEScripts from source.
# Processed 1;github.com/aragon/osx from source.
# Processed 1;github.com/villacu/ic_xlt from source.
# Processed 1;github.com/tripal/tripal_galaxy from source.
# Processed 1;github.com/domenicodigangi/DynWGraphsPaper from source.
# Processed 7;github.com/NVIDIA/DIGITS from source.
# Processed 2;github.com/kulvait/kct_cbct from source.
# Processed 1;github.com/skriegman/sim2real4designs from source.
# Processed 1;github.com/fahadsohrab/gessvdd from source.
# Processed 2;github.com/cran2367/sgt from source.
# Processed 1;github.com/gail-yxie/adawac from source.
# Processed 1;github.com/timoschick/form-context-model from source.
# Processed 1;github.com/kerteszg/EmbeddingNet from source.
# Processed 1;github.com/tkEzaki/energy-landscape-analysis from source.
# Processed 2;github.com/elifesciences-publications/gdsc-smlm from source.
# Processed 1;github.com/physimals/oxasl from source.
# Processed 1;github.com/physimals/oxasl from source.
# Processed 2;github.com/fangohr/finmag from source.
# Processed 1;github.com/inspectIT/inspectit-ocelot from source.
# Processed 2;github.com/weihuayi/fealpy from source.
# Processed 3;github.com/vistalab/scitran from source.
# Processed 2;github.com/cvjena/libmaxdiv from source.
# Processed 1;github.com/biosemantics/Measurement-Recorder-Individual-Site from source.
# Processed 1;github.com/KCL-BMEIS/ScribbleDA from source.
# Processed 1;github.com/BrainCOGS/PintoEtAl2020_subtrial_inact from source.
# Processed 2;github.com/sdtaylor/phenology_dataset_study from source.
# Processed 2;github.com/raphaelleman/SPiP from source.
# Processed 1;github.com/paralax/awesome-honeypots from source.
# Processed 2;github.com/ethereum/remix-ide from source.
# Processed 1;github.com/philipdarke/ukbb-ehr-data from source.
# Processed 1;github.com/deepmind/alphadev from source.
# Processed 2;github.com/huanglangwen/reproduce_model from source.
# Processed 1;github.com/cblakeastro/multipoles from source.
# Processed 1;github.com/YenLab/Tn5InsertPrefer from source.
# Processed 2;github.com/gersteinlab/FANCY from source.
# Processed 1;github.com/sgunderscore/hatescore-korean-hate-speech from source.
# Processed 1;github.com/etalab/piaf from source.
# Processed 2;github.com/ropensci/EML from source.
# Processed 1;github.com/poobao/stool_consistency from source.
# Processed 1;github.com/Neale-Lab/terminalMapper from source.
# Processed 1;github.com/wxy11-27/MCT-Net from source.
# Processed 1;github.com/RansML/BDF from source.
# Processed 1;github.com/danielbultrini/Clean_Dirty_Qubits from source.
# Processed 1;github.com/cbcrg/pergola-reproduce from source.
# Processed 1;github.com/xiaochunlove/Building-data-sets from source.
# Processed 1;github.com/iamanigeeit/sniper from source.
# Processed 1;github.com/Myzhao1999/LGN-Net from source.
# Processed 1;github.com/AutoViML/featurewiz from source.
# Processed 1;github.com/HaiCheung/RFCN from source.
# Processed 1;github.com/maxperutzlabs-ms/SiteToProteinNormalization_in_MultiplexProteomics from source.
# Processed 1;github.com/mmaleck/chondrocyte from source.
# Processed 1;github.com/DIDSR/mr-recon-eval-core from source.
# Processed 1;github.com/anthony-strock/ijcnn2018 from source.
# Processed 1;github.com/janjoswig/CommonNNClustering from source.
# Processed 1;github.com/swhitelam/demon from source.
# Processed 1;github.com/sequitur-g2p/sequitur-g2p from source.
# Processed 1;github.com/layer6ai-labs/rectangular-flows from source.
# Processed 1;github.com/kevinykuo/deeptriangle from source.
# Processed 1;github.com/hongweilibran/wmh_ibbmTum from source.
# Processed 1;github.com/hongweilibran/wmh_ibbmTum from source.
# Processed 1;github.com/onurbil/pde-gcn from source.
# Processed 1;github.com/shenao-zhang/StRA from source.
# Processed 1;github.com/CharliePEgan/SG-Eady-slice from source.
# Processed 2;github.com/giuferrero/NormChIP from source.
# Processed 1;github.com/spriti523/Lanthanide-richness-vs-stability from source.
# Processed 1;github.com/KazuhisaFujita/RemoveBirthUpdating from source.
# Processed 15;github.com/lgrcia/prose from source.
# Processed 1;github.com/seascapelab/FGB-eddies from source.
# Processed 2;github.com/sellalab/ForwardSimulator from source.
# Processed 1;github.com/merope82/DiskDyn from source.
# Processed 1;github.com/MRC-CBU/riksneurotools from source.
# Processed 3;github.com/murallcl/CoVSeQ_introductions from source.
# Processed 1;github.com/zsongsong/stugcn from source.
# Processed 1;github.com/MohamedAteya/BERT-Fine-Tuning-Sentence-Classification-for-CoLA from source.
# Processed 1;github.com/salinisenthil/ConnGO from source.
# Processed 1;github.com/KhiabanianLab/TuBA from source.
# Processed 2;github.com/vandersonmr/lanes-capsnet from source.
# Processed 1;github.com/cpark88/ECML-PKDD2023 from source.
# Processed 1;github.com/zhang03091354/Sync from source.
# Processed 1;github.com/mateibejan1/ad-nlp from source.
# Processed 2;github.com/researchmm/STTN from source.
# Processed 1;github.com/vigsivan/optimization-based-registration from source.
# Processed 2;github.com/X-lab-3D/PANDORA_database from source.

# %%
# see content of the file
import json
import gzip
with gzip.open("output/harshvar.json.gz", 'rt', encoding="utf-8") as f:
    for i, line in enumerate(f):
        print(line)
        if i >= 2:
            break
# Out:
# {"id": "bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF", "type": "model", "url": "https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/raw/main/README.md", "content": "--- license: apache-2.0 base_model: 01-ai/Yi-1.5-34B-32k tags: - generated_from_trainer - axolotl datasets: - cognitivecomputations/Dolphin-2.9 - teknium/OpenHermes-2.5 - m-a-p/CodeFeedback-Filtered-Instruction - cognitivecomputations/dolphin-coder - cognitivecomputations/samantha-data - microsoft/orca-math-word-problems-200k - Locutusque/function-calling-chatml - internlm/Agent-FLAN quantized_by: bartowski pipeline_tag: text-generation ---  ## Llamacpp imatrix Quantizations of dolphin-2.9.3-Yi-1.5-34B-32k  Using <a href=\"https://github.com/ggerganov/llama.cpp/\">llama.cpp</a> release <a href=\"https://github.com/ggerganov/llama.cpp/releases/tag/b3197\">b3197</a> for quantization.  Original model: https://huggingface.co/cognitivecomputations/dolphin-2.9.3-Yi-1.5-34B-32k  All quants made using imatrix option with dataset from [here](https://gist.github.com/bartowski1182/eb213dccb3571f863da82e99418f81e8)  ## Prompt format  ``` <|im_start|> system {system_prompt}<|im_end|>  <|im_start|> user {prompt}<|im_end|>  <|im_start|> assistant  ```  ## Download a file (not the whole branch) from below:  | Filename | Quant type | File Size | Description | | -------- | ---------- | --------- | ----------- | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q8_0_L.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/blob/main/dolphin-2.9.3-Yi-1.5-34B-32k-Q8_1.gguf) | Q8_0_L | 37.40GB | *Experimental*, uses f16 for embed and output weights. Please provide any feedback of differences. Extremely high quality, generally unneeded but max available quant. | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q8_0.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/blob/main/dolphin-2.9.3-Yi-1.5-34B-32k-Q8_0.gguf) | Q8_0 | 36.54GB | Extremely high quality, generally unneeded but max available quant. | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q6_K_L.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/blob/main/dolphin-2.9.3-Yi-1.5-34B-32k-Q6_K_L.gguf) | Q6_K_L | 29.29GB | *Experimental*, uses f16 for embed and output weights. Please provide any feedback of differences. Very high quality, near perfect, *recommended*. | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q6_K.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/blob/main/dolphin-2.9.3-Yi-1.5-34B-32k-Q6_K.gguf) | Q6_K | 28.21GB | Very high quality, near perfect, *recommended*. | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q5_K_L.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/blob/main/dolphin-2.9.3-Yi-1.5-34B-32k-Q5_K_L.gguf) | Q5_K_L | 25.46GB | *Experimental*, uses f16 for embed and output weights. Please provide any feedback of differences. High quality, *recommended*. | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q5_K_M.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/blob/main/dolphin-2.9.3-Yi-1.5-34B-32k-Q5_K_M.gguf) | Q5_K_M | 24.32GB | High quality, *recommended*. | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q5_K_S.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/blob/main/dolphin-2.9.3-Yi-1.5-34B-32k-Q5_K_S.gguf) | Q5_K_S | 23.70GB | High quality, *recommended*. | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q4_K_L.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/blob/main/dolphin-2.9.3-Yi-1.5-34B-32k-Q4_K_L.gguf) | Q4_K_L | 21.85GB | *Experimental*, uses f16 for embed and output weights. Please provide any feedback of differences. Good quality, uses about 4.83 bits per weight, *recommended*. | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q4_K_M.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-34B-32k-GGUF/blob/main/dolphin-2.9.3-Yi-1.5-34B-32k-Q4_K_M.gguf) | Q4_K_M | 20.65GB | Good quality, uses about 4.83 bits per weight, *recommended*. | | [dolphin-2.9.3-Yi-1.5-34B-32k-Q4_K_S.gguf](https://huggingface.co/bartowski/dolphin-2.9.3-Yi-1.5-3 ...
#
# {"id": "mradermacher/Boundary-4x7b-MoE-i1-GGUF", "type": "model", "url": "https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/raw/main/README.md", "content": "--- base_model: NotAiLOL/Boundary-4x7b-MoE language: - en library_name: transformers license: apache-2.0 quantized_by: mradermacher tags: - moe - merge - mergekit - HuggingFaceH4/zephyr-7b-beta - mistralai/Mistral-7B-Instruct-v0.2 - teknium/OpenHermes-2.5-Mistral-7B - meta-math/MetaMath-Mistral-7B - Mistral --- ## About  <!-- ### quantize_version: 1 --> <!-- ### output_tensor_quantised: 1 --> <!-- ### convert_type:  --> <!-- ### vocab_type:  --> weighted/imatrix quants of https://huggingface.co/NotAiLOL/Boundary-4x7b-MoE  <!-- provided-files --> static quants are available at https://huggingface.co/mradermacher/Boundary-4x7b-MoE-GGUF ## Usage  If you are unsure how to use GGUF files, refer to one of [TheBloke's READMEs](https://huggingface.co/TheBloke/KafkaLM-70B-German-V0.1-GGUF) for more details, including on how to concatenate multi-part files.  ## Provided Quants  (sorted by size, not necessarily quality. IQ-quants are often preferable over similar sized non-IQ quants)  | Link | Type | Size/GB | Notes | |:-----|:-----|--------:|:------| | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ1_S.gguf) | i1-IQ1_S | 5.1 | for the desperate | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ1_M.gguf) | i1-IQ1_M | 5.6 | mostly desperate | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ2_XXS.gguf) | i1-IQ2_XXS | 6.5 |  | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ2_XS.gguf) | i1-IQ2_XS | 7.2 |  | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ2_S.gguf) | i1-IQ2_S | 7.4 |  | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ2_M.gguf) | i1-IQ2_M | 8.1 |  | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-Q2_K.gguf) | i1-Q2_K | 8.9 | IQ3_XXS probably better | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ3_XXS.gguf) | i1-IQ3_XXS | 9.4 | lower quality | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ3_XS.gguf) | i1-IQ3_XS | 10.0 |  | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-Q3_K_S.gguf) | i1-Q3_K_S | 10.5 | IQ3_XS probably better | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ3_S.gguf) | i1-IQ3_S | 10.6 | beats Q3_K* | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ3_M.gguf) | i1-IQ3_M | 10.7 |  | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-Q3_K_M.gguf) | i1-Q3_K_M | 11.7 | IQ3_S probably better | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-Q3_K_L.gguf) | i1-Q3_K_L | 12.6 | IQ3_M probably better | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-IQ4_XS.gguf) | i1-IQ4_XS | 13.0 |  | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-Q4_0.gguf) | i1-Q4_0 | 13.8 | fast, low quality | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-Q4_K_S.gguf) | i1-Q4_K_S | 13.8 | optimal size/speed/quality | | [GGUF](https://huggingface.co/mradermacher/Boundary-4x7b-MoE-i1-GGUF/resolve/main/Boundary-4x7b-MoE.i1-Q4_K_M.gguf) | i1-Q4_K_M | 14.7 | fast, recommended | | [GGUF](https://huggingface.co/mrader ...
#
# {"id": "Weyaxi/Einstein-v4-7B", "type": "model", "url": "https://huggingface.co/Weyaxi/Einstein-v4-7B/raw/main/README.md", "content": "--- language: - en license: other tags: - axolotl - generated_from_trainer - Mistral - instruct - finetune - chatml - gpt4 - synthetic data - science - physics - chemistry - biology - math base_model: mistralai/Mistral-7B-v0.1 datasets: - allenai/ai2_arc - camel-ai/physics - camel-ai/chemistry - camel-ai/biology - camel-ai/math - metaeval/reclor - openbookqa - mandyyyyii/scibench - derek-thomas/ScienceQA - TIGER-Lab/ScienceEval - jondurbin/airoboros-3.2 - LDJnr/Capybara - Cot-Alpaca-GPT4-From-OpenHermes-2.5 - STEM-AI-mtl/Electrical-engineering - knowrohit07/saraswati-stem - sablo/oasst2_curated - glaiveai/glaive-code-assistant - lmsys/lmsys-chat-1m - TIGER-Lab/MathInstruct - bigbio/med_qa - meta-math/MetaMathQA-40K - openbookqa - piqa - metaeval/reclor - derek-thomas/ScienceQA - scibench - sciq - Open-Orca/SlimOrca - migtissera/Synthia-v1.3 - TIGER-Lab/ScienceEval model-index: - name: Einstein-v4-7B   results:   - task:       type: text-generation       name: Text Generation     dataset:       name: AI2 Reasoning Challenge (25-Shot)       type: ai2_arc       config: ARC-Challenge       split: test       args:         num_few_shot: 25     metrics:     - type: acc_norm       value: 64.68       name: normalized accuracy     source:       url: https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard?query=Weyaxi/Einstein-v4-7B       name: Open LLM Leaderboard   - task:       type: text-generation       name: Text Generation     dataset:       name: HellaSwag (10-Shot)       type: hellaswag       split: validation       args:         num_few_shot: 10     metrics:     - type: acc_norm       value: 83.75       name: normalized accuracy     source:       url: https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard?query=Weyaxi/Einstein-v4-7B       name: Open LLM Leaderboard   - task:       type: text-generation       name: Text Generation     dataset:       name: MMLU (5-Shot)       type: cais/mmlu       config: all       split: test       args:         num_few_shot: 5     metrics:     - type: acc       value: 62.31       name: accuracy     source:       url: https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard?query=Weyaxi/Einstein-v4-7B       name: Open LLM Leaderboard   - task:       type: text-generation       name: Text Generation     dataset:       name: TruthfulQA (0-shot)       type: truthful_qa       config: multiple_choice       split: validation       args:         num_few_shot: 0     metrics:     - type: mc2       value: 55.15     source:       url: https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard?query=Weyaxi/Einstein-v4-7B       name: Open LLM Leaderboard   - task:       type: text-generation       name: Text Generation     dataset:       name: Winogrande (5-shot)       type: winogrande       config: winogrande_xl       split: validation       args:         num_few_shot: 5     metrics:     - type: acc       value: 76.24       name: accuracy     source:       url: https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard?query=Weyaxi/Einstein-v4-7B       name: Open LLM Leaderboard   - task:       type: text-generation       name: Text Generation     dataset:       name: GSM8k (5-shot)       type: gsm8k       config: main       split: test       args:         num_few_shot: 5     metrics:     - type: acc       value: 57.62       name: accuracy     source:       url: https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard?query=Weyaxi/Einstein-v4-7B       name: Open LLM Leaderboard   - task:       type: text-generation       name: Text Generation     dataset:       name: IFEval (0-Shot)       type: HuggingFaceH4/ifeval       args:         num_few_shot: 0     metrics:     - type: inst_level_strict_acc and prompt_level_strict_acc       value: 47.08       name: strict accuracy     source:       url: https://huggingface.co/spaces/open-l ...
